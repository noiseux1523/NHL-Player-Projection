# %% [markdown]
# # Utilities

# %%
import pandas as pd
import numpy as np
import re
import math

# %% [markdown]
# ---
# # Read Datasets

# %%
nhl13 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2012-13.csv', encoding = "utf-8")
# nhl13 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2012-13.csv', encoding = "utf-8")
# nhl13 = pd.read_csv('~/Dropbox/NHL 2012-13.csv', encoding = "utf-8")
nhl13.columns = [str(col) + '_13' for col in nhl13.columns]

# %%
nhl13['Name'] = nhl13.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_13"]}{player["First Name_13"]}').upper(), axis=1)
nhl13.drop('BTN Code_13', axis=1, inplace=True)

# %%
nhl13.set_index('Name', inplace=True)

# %%
nhl13.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl13.head()
# Out:
#                   #_13      DOB_13 Birth City_13 S/P_13 Ctry_13  HT_13  Wt_13  \
# Name
# ABDELKADERJUSTIN   8.0  Feb 25 '87      Muskegon     MI     USA     73    219
# ADAMLUKE          72.0  Jun 18 '90    St. John's     NF     CAN     74    206
# ADAMSCRAIG        27.0  Apr 26 '77         Seria    NaN     BRN     72    197
# AKESONJASON       42.0  Jun 03 '90        Ottawa     ON     CAN     70    190
# ALBERTSANDREW     41.0  Jun 30 '81   Minneapolis     MN     USA     77    218
#
#                  S_13 Rk_13  Age_13   ...   GVT/G_13 GVT/60_13 Full_13  \
# Name                                  ...
# ABDELKADERJUSTIN    L   NaN      26   ...       0.07      0.29    99.0
# ADAMLUKE            L   NaN      23   ...       0.08      0.46    15.0
# ADAMSCRAIG          R   NaN      36   ...       0.02      0.12    99.0
# AKESONJASON         R     Y      23   ...       0.50      2.42     6.0
# ALBERTSANDREW       L   NaN      32   ...      -0.05     -0.18    99.0
#
#                  LTIR_13 SOIR_13  Ginj_13  Injury_13  Cap Cost_13  Bonuses_13  \
# Name
# ABDELKADERJUSTIN     0.0     0.0      NaN        NaN   $1,800,000          $0
# ADAMLUKE             0.0     0.0      NaN        NaN     $119,318     $87,500
# ADAMSCRAIG           0.0     0.0      NaN        NaN     $675,000          $0
# AKESONJASON          0.0     0.0      NaN        NaN      $43,333    $185,000
# ALBERTSANDREW        0.0     0.0      NaN        NaN   $1,225,000          $0
#
#                   GVS_13
# Name
# ABDELKADERJUSTIN     1.1
# ADAMLUKE             0.2
# ADAMSCRAIG           0.8
# AKESONJASON          0.5
# ALBERTSANDREW       -2.4
#
# [5 rows x 226 columns]

# %%
nhl14 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2013-14.csv', encoding = "utf-8")
# nhl14 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2013-14.csv', encoding = "utf-8")
# nhl14 = pd.read_csv('~/Dropbox/NHL 2013-14.csv', encoding = "utf-8")
nhl14.columns = [str(col) + '_14' for col in nhl14.columns]

# %%
nhl14['Name'] = nhl14.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_14"]}{player["First Name_14"]}').upper(), axis=1)
nhl14.drop('BTN Code_14', axis=1, inplace=True)

# %%
nhl14.set_index('Name', inplace=True)

# %%
nhl14.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl14.head()
# Out:
#                   #_14      DOB_14 Birth City_14 S/P_14 Ctry_14  HT_14  Wt_14  \
# Name
# ABBOTTSPENCER     56.0  Apr 30 '88      Hamilton     ON     CAN     69    170
# ABDELKADERJUSTIN   8.0  Feb 25 '87      Muskegon     MI     USA     73    219
# ACTONWILL         41.0  Jul 16 '87         Edina     MN     USA     73    199
# ADAMLUKE          72.0  Jun 18 '90    St. John's     NL     CAN     74    206
# ADAMSCRAIG        27.0  Apr 26 '77         Seria    NaN     BRN     72    200
#
#                  S_14  Draft_14  Round_14   ...    GVT/G_14 GVT/60_14  \
# Name                                        ...
# ABBOTTSPENCER       R       NaN       NaN   ...       -0.40     -4.56
# ABDELKADERJUSTIN    L    2005.0       2.0   ...        0.06      0.24
# ACTONWILL           L       NaN       NaN   ...        0.05      0.39
# ADAMLUKE            L    2008.0       2.0   ...       -0.05     -0.23
# ADAMSCRAIG          R    1996.0       9.0   ...        0.01      0.06
#
#                   Full_14 LTIR_14 SOIR_14 Ginj_14    Injury_14  Cap Cost_14  \
# Name
# ABBOTTSPENCER         NaN     NaN     NaN     NaN          NaN     650000.0
# ABDELKADERJUSTIN      NaN     NaN     NaN    12.0  Head, Groin    1800000.0
# ACTONWILL             NaN     NaN     NaN     NaN          NaN     680000.0
# ADAMLUKE              NaN     NaN     NaN     NaN          NaN     735000.0
# ADAMSCRAIG            NaN     NaN     NaN     NaN          NaN     700000.0
#
#                  Bonuses_14  GVS_14
# Name
# ABBOTTSPENCER           NaN    -1.5
# ABDELKADERJUSTIN        NaN     1.0
# ACTONWILL               NaN     0.4
# ADAMLUKE                NaN    -1.9
# ADAMSCRAIG              NaN    -0.2
#
# [5 rows x 102 columns]

# %%
nhl15 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2014-15.csv', encoding = "utf-8")
# nhl15 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2014-15.csv', encoding = "utf-8")
# nhl15 = pd.read_csv('~/Dropbox/NHL 2014-15.csv', encoding = "utf-8")
nhl15.columns = [str(col) + '_15' for col in nhl15.columns]

# %%
nhl15['Name'] = nhl15.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_15"]}{player["First Name_15"]}').upper(), axis=1)

# %%
nhl15.set_index('Name', inplace=True)

# %%
nhl15.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl15.head()
# Out:
#                   #_15      DOB_15 Birth City_15 S/P_15 Ctry_15 Nat_15  HT_15  \
# Name
# ABDELKADERJUSTIN   8.0  Feb 25 '87      Muskegon     MI     USA     US     74
# ACTONWILL         41.0  Jul 16 '87         Edina     MN     USA     US     75
# ADAMLUKE          25.0  Jun 18 '90    St. John's     NL     CAN     CA     74
# ADAMSCRAIG        27.0  Apr 26 '77         Seria    NaN     BRN    NaN     72
# AGOZZINOANDREW    32.0  Jan 03 '91     Kleinburg     ON     CAN     CA     70
#
#                   Wt_15 S_15  Draft_15  ...    dFAImpact_15  \
# Name                                    ...
# ABDELKADERJUSTIN    218    L    2005.0  ...           -49.4
# ACTONWILL           202    L       NaN  ...            -6.3
# ADAMLUKE            206    L    2008.0  ...            -4.1
# ADAMSCRAIG          200    R    1996.0  ...            -1.2
# AGOZZINOANDREW      187    L       NaN  ...             1.1
#
#                   dFenwickImpact_15 dFenwick60_15  Days_15 Ginj_15  \
# Name
# ABDELKADERJUSTIN               -9.4          -0.6      186    11.0
# ACTONWILL                      10.4          22.6       29     NaN
# ADAMLUKE                        1.0           3.3        5     NaN
# ADAMSCRAIG                    -19.4          -2.4      186     5.0
# AGOZZINOANDREW                  0.4           2.3        2     NaN
#
#                        Injury_15 Cap Cost_15 CHIP_15  Bonuses_15 GVS_15
# Name
# ABDELKADERJUSTIN  Hand, Shoulder       1.800   0.088         0.0    5.3
# ACTONWILL                    NaN       0.106   0.000         0.0   -0.4
# ADAMLUKE                     NaN       0.017   0.000         0.0   -0.1
# ADAMSCRAIG           Undisclosed       0.700   0.043         0.0    1.0
# AGOZZINOANDREW               NaN       0.006   0.000         0.0    0.3
#
# [5 rows x 120 columns]

# %%
nhl16 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2015-16.csv', encoding = "utf-8")
# nhl16 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2015-16.csv', encoding = "utf-8")
# nhl16 = pd.read_csv('~/Dropbox/NHL 2015-16.csv', encoding = "utf-8")
nhl16.columns = [str(col) + '_16' for col in nhl16.columns]

# %%
nhl16['Name'] = nhl16.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_16"]}{player["First Name_16"]}').upper(), axis=1)

# %%
nhl16.set_index('Name', inplace=True)

# %%
nhl16.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl16.head()
# Out:
#                   #_16      DOB_16 Birth City_16 S/P_16 Ctry_16 Nat_16  HT_16  \
# Name
# ABDELKADERJUSTIN   8.0  1987-02-25      Muskegon     MI     USA    USA     74
# ACCIARINOEL       55.0  1991-12-01      Johnston     RI     USA    USA     70
# AGOSTINOKENNY     51.0  1992-04-30    Morristown     NJ     USA    USA     72
# AGOZZINOANDREW    28.0  1991-01-03     Kleinburg     ON     CAN    CAN     70
# ALZNERKARL        27.0  1988-09-24       Burnaby     BC     CAN    CAN     74
#
#                   Wt_16 S_16  Draft_16   ...    3rd Star_16  Days_16 Ginj_16  \
# Name                                     ...
# ABDELKADERJUSTIN    218    L    2005.0   ...              4      186       0
# ACCIARINOEL         208    R       NaN   ...              0       40       0
# AGOSTINOKENNY       202    L    2010.0   ...              0        6       0
# AGOZZINOANDREW      187    L       NaN   ...              0       19       0
# ALZNERKARL          214    L    2007.0   ...              1      186       0
#
#                   Injury_16 Salary_16 Cap Hit_16 Cap Cost_16 CHIP_16  \
# Name
# ABDELKADERJUSTIN        NaN     2.250      1.800       1.800       0
# ACCIARINOEL             NaN     0.693      0.793       0.170       0
# AGOSTINOKENNY           NaN     0.830      0.830       0.024       0
# AGOZZINOANDREW          NaN     0.600      0.600       0.061       0
# ALZNERKARL              NaN     2.800      2.800       2.800       0
#
#                  Bonuses_16  GVS_16
# Name
# ABDELKADERJUSTIN        0.0     1.6
# ACCIARINOEL             0.0    -1.0
# AGOSTINOKENNY           0.0    -0.3
# AGOZZINOANDREW          0.0     0.1
# ALZNERKARL              0.0     3.8
#
# [5 rows x 129 columns]

# %%
nhl17 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2016-17.csv', encoding = "utf-8", sep='\t')
# nhl17 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2016-17.csv', encoding = "utf-8", sep='\t')
# nhl17 = pd.read_csv('~/Dropbox/NHL 2016-17.csv', encoding = "utf-8", sep='\t')
nhl17.columns = [str(col) + '_17' for col in nhl17.columns]

# %%
nhl17['Name'] = nhl17.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_17"]}{player["First Name_17"]}').upper(), axis=1)

# %%
nhl17.set_index('Name', inplace=True)

# %%
nhl17.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl17.head()
# Out:
#                      Born_17     City_17 Pr/St_17 Cntry_17 Nat_17  Ht_17  \
# Name
# ABBOTTSPENCER     1988-04-30    Hamilton       ON      CAN    CAN     69
# ABDELKADERJUSTIN  1987-02-25    Muskegon       MI      USA    USA     74
# ABERGPONTUS       1993-09-23   Stockholm      NaN      SWE    SWE     71
# ACCIARINOEL       1991-12-01    Johnston       RI      USA    USA     70
# AGOSTINOKENNY     1992-04-30  Morristown       NJ      USA    USA     72
#
#                   Wt_17  DftYr_17  DftRd_17  Ovrl_17      ...       1st_17  \
# Name                                                      ...
# ABBOTTSPENCER       170       NaN       NaN      NaN      ...          NaN
# ABDELKADERJUSTIN    218    2005.0       2.0     42.0      ...          0.0
# ABERGPONTUS         196    2012.0       2.0     37.0      ...          0.0
# ACCIARINOEL         208       NaN       NaN      NaN      ...          0.0
# AGOSTINOKENNY       202    2010.0       5.0    140.0      ...          0.0
#
#                   2nd_17 3rd_17 MGL_17             Injuries_17      CHIP_17  \
# Name
# ABBOTTSPENCER        NaN    NaN    NaN                     NaN          NaN
# ABDELKADERJUSTIN     0.0    1.0   18.0        Lower body, Knee  $932 926,83
# ABERGPONTUS          0.0    1.0    NaN                     NaN          NaN
# ACCIARINOEL          0.0    1.0   15.0  Lower body, Upper body  $144 969,51
# AGOSTINOKENNY        1.0    0.0    NaN                     NaN          NaN
#
#                   NMC_17  Status_17      Salary_17     Cap Hit_17
# Name
# ABBOTTSPENCER        NaN        UFA    $575 000,00    $575 000,00
# ABDELKADERJUSTIN     NTC        UFA  $5 500 000,00  $4 250 000,00
# ABERGPONTUS          NaN        RFA    $842 500,00    $780 833,00
# ACCIARINOEL          NaN        RFA    $892 500,00    $792 500,00
# AGOSTINOKENNY        NaN        UFA    $625 000,00    $625 000,00
#
# [5 rows x 167 columns]

# %%
nhl17pp = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2016-17-5on4.csv', encoding = "utf-8")
# nhl17pp = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2016-17-5on4.csv', encoding = "utf-8")
# nhl17pp = pd.read_csv('~/Dropbox/NHL 2016-17-5on4.csv', encoding = "utf-8")
nhl17pp.columns = [str(col) + '_17pp' for col in nhl17pp.columns]

# %%
nhl17pp['Name'] = nhl17pp.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_17pp"]}{player["First Name_17pp"]}').upper(), axis=1)

# %%
nhl17pp.set_index('Name', inplace=True)

# %%
nhl17pp.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl17pp.head()
# Out:
#                  Last Name_17pp First Name_17pp Position_17pp Team_17pp  \
# Name
# ABBOTTSPENCER            Abbott         Spencer            LW       CHI
# ABDELKADERJUSTIN     Abdelkader          Justin         LW/RW       DET
# ABERGPONTUS               Aberg          Pontus            LW       NSH
# ACCIARINOEL             Acciari            Noel             C       BOS
# AGOSTINOKENNY          Agostino           Kenny            LW       STL
#
#                   GP_17pp  G_17pp  A_17pp  A1_17pp  PTS_17pp  PTS/60_17pp  \
# Name
# ABBOTTSPENCER           1       0       0      NaN         0         0.00
# ABDELKADERJUSTIN       64       5       2      0.0         7         2.93
# ABERGPONTUS            15       0       0      0.0         0         0.00
# ACCIARINOEL            29       0       0      NaN         0         0.00
# AGOSTINOKENNY           7       0       1      1.0         1         6.60
#
#                     ...    OppFF60_17pp  OppFA60_17pp  OppSF60_17pp  \
# Name                ...
# ABBOTTSPENCER       ...             NaN           NaN           NaN
# ABDELKADERJUSTIN    ...            11.0          71.2           8.9
# ABERGPONTUS         ...            10.9          70.1           8.5
# ACCIARINOEL         ...             NaN           NaN           NaN
# AGOSTINOKENNY       ...            11.1          74.3           8.7
#
#                   OppSA60_17pp  OppGF60_17pp OppGA60_17pp TOI.QoC.1_17pp  \
# Name
# ABBOTTSPENCER              NaN           NaN          NaN            NaN
# ABDELKADERJUSTIN          51.0          0.82         6.25           30.2
# ABERGPONTUS               50.7          0.82         5.80           31.8
# ACCIARINOEL                NaN           NaN          NaN           30.1
# AGOSTINOKENNY             53.2          0.78         6.51           29.5
#
#                  CF.QoC.1_17pp xGF.QoC_17pp Pace_17pp
# Name
# ABBOTTSPENCER              NaN          NaN       0.0
# ABDELKADERJUSTIN          49.7         49.9     103.1
# ABERGPONTUS               52.1         52.0      28.1
# ACCIARINOEL               49.3         49.6       0.0
# AGOSTINOKENNY             49.1         49.5      72.0
#
# [5 rows x 150 columns]

# %%
nhl18 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2017-18.csv', encoding = "utf-8", sep='\t')
# nhl18 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2017-18.csv', encoding = "utf-8", sep='\t')
# nhl18 = pd.read_csv('~/Dropbox/NHL 2017-18.csv', encoding = "utf-8", sep='\t')
nhl18.columns = [str(col) + '_18' for col in nhl18.columns]

# %%
nhl18['Name'] = nhl18.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_18"]}{player["First Name_18"]}').upper(), axis=1)

# %%
nhl18.set_index('Name', inplace=True)

# %%
nhl18.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl18.head()
# Out:
#                   Born_18     City_18 Pr/St_18 Cntry_18 Nat_18  Ht_18  Wt_18  \
# Name
# HAYESJIMMY     1989-11-21  Dorchester       MA      USA    USA     77    215
# LEHTERAJORI    1987-12-23    Helsinki      NaN      FIN    FIN     74    212
# STONEMICHAEL   1990-06-07    Winnipeg       MB      CAN    CAN     75    210
# HARTNELLSCOTT  1982-04-18      Regina       SK      CAN    CAN     74    215
# HAINSEYRON     1981-03-24      Bolton       CT      USA    USA     75    205
#
#                DftYr_18  DftRd_18  Ovrl_18       ...        A.1_18  PTS.1_18  \
# Name                                             ...
# HAYESJIMMY       2008.0       2.0     60.0       ...            55       109
# LEHTERAJORI      2008.0       3.0     65.0       ...            75       108
# STONEMICHAEL     2008.0       3.0     69.0       ...            83       112
# HARTNELLSCOTT    2000.0       1.0      6.0       ...           380       707
# HAINSEYRON       2000.0       1.0     13.0       ...           223       276
#
#                +/-.1_18  PIM.1_18  Shot_18 TOI.4_18 OPS.1_18 DPS.1_18 PS.1_18  \
# Name
# HAYESJIMMY          -29       149      530     4120      6,9      3,2    10,1
# LEHTERAJORI          19       134      298     4109      4,2      5,5     9,7
# STONEMICHAEL        -46       238      652     8141      5,5     14,8    20,4
# HARTNELLSCOTT        66      1809     2777    19535     57,8     23,6    81,4
# HAINSEYRON          -61       410     1292    20909     10,5       41    51,5
#
#                Unnamed: 189_18
# Name
# HAYESJIMMY                 8,4
# LEHTERAJORI                6,6
# STONEMICHAEL               7,2
# HARTNELLSCOTT             15,8
# HAINSEYRON                  21
#
# [5 rows x 190 columns]

# %%
nhl18pp = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL 2017-18-5on4.csv', encoding = "utf-8")
# nhl18pp = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2017-18-5on4.csv', encoding = "utf-8")
# nhl18pp = pd.read_csv('~/Dropbox/NHL 2017-18-5on4.csv', encoding = "utf-8")
nhl18pp.columns = [str(col) + '_18pp' for col in nhl18pp.columns]

# %%
# ATTENTION LAST NAME ET FIRST NAME INVERSE

nhl18pp['Name'] = nhl18pp.apply(lambda player: re.sub(r'\W+', '', f'{player["First Name_18pp"]}{player["Last Name_18pp"]}').upper(), axis=1)

# %%
nhl18pp.set_index('Name', inplace=True)

# %%
nhl18pp.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl18pp.head()
# Out:
#               Last Name_18pp First Name_18pp Position_18pp Team_18pp  GP_18pp  \
# Name
# HAYESJIMMY             Jimmy           Hayes            RW       NJD       33
# LEHTERAJORI             Jori         Lehtera             C       PHI       62
# STONEMICHAEL         Michael           Stone             D       CGY       82
# HARTNELLSCOTT          Scott        Hartnell            LW       NSH       62
# HAINSEYRON               Ron         Hainsey             D       TOR       80
#
#                G_18pp  A_18pp  A1_18pp  PTS_18pp  PTS/60_18pp    ...      \
# Name                                                             ...
# HAYESJIMMY          1       0        0         1         1.17    ...
# LEHTERAJORI         0       0        0         0         0.00    ...
# STONEMICHAEL        0       1        1         1         1.27    ...
# HARTNELLSCOTT       2       3        2         5         3.96    ...
# HAINSEYRON          1       0        0         1         5.46    ...
#
#                xGF/60.QoT_18pp xGA/60.QoT_18pp  TOI.QoC_18pp  CF.QoC_18pp  \
# Name
# HAYESJIMMY                7.20            1.36         37.70        13.19
# LEHTERAJORI               5.32            0.78         36.91        12.83
# STONEMICHAEL              8.37            1.07         36.23        12.33
# HARTNELLSCOTT             6.64            0.72         38.10        12.92
# HAINSEYRON                7.87            0.88         33.16        14.67
#
#                CF/60.QoC_18pp  CA/60.QoC_18pp  xGF.QoC_18pp  xGF/60.QoC_18pp  \
# Name
# HAYESJIMMY              15.13          100.55          7.20             1.05
# LEHTERAJORI             14.50           99.67          5.32             0.97
# STONEMICHAEL            14.41          105.14          8.37             1.02
# HARTNELLSCOTT           15.02          101.55          6.64             1.08
# HAINSEYRON              16.58           97.67          7.87             1.10
#
#               xGA/60.QoC_18pp  Pace_18pp
# Name
# HAYESJIMMY               7.19      117.0
# LEHTERAJORI              6.83      100.6
# STONEMICHAEL             7.60       96.7
# HARTNELLSCOTT            7.27      100.1
# HAINSEYRON               6.96      125.3
#
# [5 rows x 144 columns]

# %% [markdown]
# ---
# # Preprocessing
#
# ## Join by Name

# %%
nhl13.shape
# Out:
# (839, 226)

# %%
nhl14.shape
# Out:
# (886, 102)

# %%
nhl13_14 = nhl14.join(nhl13)
nhl13_14 = pd.concat([nhl13_14, nhl13], sort=False)
nhl13_14 = nhl13_14[~nhl13_14.index.duplicated(keep='first')]

# %%
nhl13_14.shape
# Out:
# (1024, 328)

# %%
nhl14_15 = nhl15.join(nhl13_14)
nhl14_15 = pd.concat([nhl14_15, nhl13_14], sort=False)
nhl14_15 = nhl14_15[~nhl14_15.index.duplicated(keep='first')]

# %%
nhl14_15.shape
# Out:
# (1161, 448)

# %%
nhl15_16 = nhl16.join(nhl14_15)
nhl15_16 = pd.concat([nhl15_16, nhl14_15], sort=False)
nhl15_16 = nhl15_16[~nhl15_16.index.duplicated(keep='first')]

# %%
nhl15_16.shape
# Out:
# (1314, 577)

# %%
nhl16_17 = nhl17.join(nhl15_16)
nhl16_17 = pd.concat([nhl16_17, nhl15_16], sort=False)
nhl16_17 = nhl16_17[~nhl16_17.index.duplicated(keep='first')]

# %%
nhl16_17.shape
# Out:
# (1467, 744)

# %%
nhl16_17pp = nhl17pp.join(nhl16_17)
nhl16_17pp = pd.concat([nhl16_17pp, nhl16_17], sort=False)
nhl16_17pp = nhl16_17pp[~nhl16_17pp.index.duplicated(keep='first')]

# %%
nhl16_17pp.shape
# Out:
# (1468, 894)

# %%
nhl17_18pp = nhl18pp.join(nhl16_17pp)
nhl17_18pp = pd.concat([nhl17_18pp, nhl16_17pp], sort=False)
nhl17_18pp = nhl17_18pp[~nhl17_18pp.index.duplicated(keep='first')]

# %%
nhl17_18pp.shape
# Out:
# (1596, 1038)

# %%
nhl = nhl18.join(nhl17_18pp)
nhl = pd.concat([nhl, nhl17_18pp], sort=False)
nhl = nhl[~nhl.index.duplicated(keep='first')]

# %%
nhl.shape
# Out:
# (1596, 1228)

# %% [markdown]
# ## Filter columns

# %%
# add 17 et 18 PPTOI des xls

# PAX: Points above expectations, based on previous average career points per game
# GC: Goals Created, which is half-point for a goal, and a variable amount depending on the team's assists per goal
# SCF: Team scoring chances while this player was on the ice
# WAR: Wins above replacement, a catch-all stat that measures a player's offensive contributions in terms of wins
# ZS%: Zone start percentage
# GS: The player's combined game score, quality of games played, averaged per game

nhl = nhl[['Last Name_18', 'First Name_18', 'Team_18', 'Age_18', 'Position_18', \
           'GP_13', 'GP_14', 'GP_15', 'GP_16', 'GP_17', 'GP_18', \
           'G_13', 'G_14', 'G_15', 'G_16', 'G_17', 'G_18', \
           'A_13', 'A_14', 'A_15', 'A_16', 'A_17', 'A_18', \
           'PTS_13', 'PTS_14', 'PTS_15', 'PTS_16', 'PTS_17', 'PTS_18', 'PAX_18', \
           'Sh%_13', 'Sh%_14', 'Sh%_15', 'Sh%_16', 'SH%_17', 'SH%_18', \
           'Sh_13', 'Sh_14', 'Sh_15', 'Sh_16', 'iSF_17', 'iSF_18', \
           'TOI/G_13', 'TOI/G_14', 'TOI/G_15', 'TOI/G_16', 'TOI/GP_17', 'TOI/GP_18', \
           'TOI/GP_17pp', 'TOI/GP_18pp', \
           'ZS%_18', \
           'GC_18', 'SCF_17', 'SCF_18', 'GS/G_17', 'GS/G_18', 'OWAR_18', 'OPS_17', 'OPS_18', \
           'PDO_17', 'PDO_18', \
           'iCF_17', 'iCF_18', \
           'iFF_17', 'iFF_18', \
           'Star_18', \
           'Salary_18', \
           'Cap Cost_13', 'Cap Cost_14', 'Cap Cost_15', 'Cap Hit_16', 'Cap Hit_17', 'Cap Hit_18']]

nhl.rename(columns={'TOI/GP_17': 'TOI/G_17', 'TOI/GP_18': 'TOI/G_18', 'SH%_17': 'Sh%_17', 'SH%_18': 'Sh%_18',
                   'Sh_13': 'iSF_13', 'Sh_14': 'iSF_14', 'Sh_15': 'iSF_15', 'Sh_16': 'iSF_16'}, inplace=True)
nhl.head()
# Out:
#                  Last Name_18 First Name_18   Team_18  Age_18 Position_18  \
# Name
# ABDELKADERJUSTIN   Abdelkader        Justin       DET    30.0          LW
# ABERGPONTUS             Aberg        Pontus  NSH, EDM    24.0          LW
# ACCIARINOEL           Acciari          Noel       BOS    26.0           C
# AGOSTINOKENNY        Agostino         Kenny       BOS    25.0          LW
# AHOSEBASTIAN              Aho     Sebastian       NYI    21.0           D
#
#                   GP_13  GP_14  GP_15  GP_16  GP_17     ...      iFF_17  \
# Name                                                    ...
# ABDELKADERJUSTIN   48.0   70.0   71.0   82.0   64.0     ...       138.0
# ABERGPONTUS         NaN    NaN    NaN    NaN   15.0     ...        15.0
# ACCIARINOEL         NaN    NaN    NaN   19.0   29.0     ...         NaN
# AGOSTINOKENNY       NaN    8.0    NaN    2.0    7.0     ...        24.0
# AHOSEBASTIAN        NaN    NaN    NaN    NaN   82.0     ...       285.0
#
#                   iFF_18  Star_18   Salary_18  Cap Cost_13  Cap Cost_14  \
# Name
# ABDELKADERJUSTIN   164.0    2,193  $5 000 000   $1,800,000    1800000.0
# ABERGPONTUS        101.0   0,9651    $650 000          NaN          NaN
# ACCIARINOEL         92.0   0,7466    $700 000          NaN          NaN
# AGOSTINOKENNY       16.0   0,0125    $875 000          NaN     900000.0
# AHOSEBASTIAN        33.0   0,4247    $742 500          NaN          NaN
#
#                   Cap Cost_15  Cap Hit_16     Cap Hit_17  Cap Hit_18
# Name
# ABDELKADERJUSTIN          1.8       1.800  $4 250 000,00  $4 250 000
# ABERGPONTUS               NaN         NaN    $780 833,00    $650 000
# ACCIARINOEL               NaN       0.793    $792 500,00    $725 000
# AGOSTINOKENNY             NaN       0.830    $625 000,00    $875 000
# AHOSEBASTIAN              NaN         NaN    $925 000,00    $770 000
#
# [5 rows x 73 columns]

# %%
# Rename columns
nhl.rename(columns={'Age_18': 'Age', 'Last Name_18': 'Last_Name', 'First Name_18': 'First_Name', 'Team_18': 'Team',
                    'Position_18': 'Position', 'Star_18': 'Star', 
                    'TOI/GP_17pp': 'PPTOI/GP_17', 'TOI/GP_18pp': 'PPTOI/GP_18'}, inplace=True)

# %%
nhl.columns
# Out:
# Index(['Last_Name', 'First_Name', 'Team', 'Age', 'Position', 'GP_13', 'GP_14',
#        'GP_15', 'GP_16', 'GP_17', 'GP_18', 'G_13', 'G_14', 'G_15', 'G_16',
#        'G_17', 'G_18', 'A_13', 'A_14', 'A_15', 'A_16', 'A_17', 'A_18',
#        'PTS_13', 'PTS_14', 'PTS_15', 'PTS_16', 'PTS_17', 'PTS_18', 'PAX_18',
#        'Sh%_13', 'Sh%_14', 'Sh%_15', 'Sh%_16', 'Sh%_17', 'Sh%_18', 'iSF_13',
#        'iSF_14', 'iSF_15', 'iSF_16', 'iSF_17', 'iSF_18', 'TOI/G_13',
#        'TOI/G_14', 'TOI/G_15', 'TOI/G_16', 'TOI/G_17', 'TOI/G_18',
#        'PPTOI/GP_17', 'PPTOI/GP_18', 'ZS%_18', 'GC_18', 'SCF_17', 'SCF_18',
#        'GS/G_17', 'GS/G_18', 'OWAR_18', 'OPS_17', 'OPS_18', 'PDO_17', 'PDO_18',
#        'iCF_17', 'iCF_18', 'iFF_17', 'iFF_18', 'Star', 'Salary_18',
#        'Cap Cost_13', 'Cap Cost_14', 'Cap Cost_15', 'Cap Hit_16', 'Cap Hit_17',
#        'Cap Hit_18'],
#       dtype='object')

# %% [markdown]
# ---
# ## Feature Engineering
#
# ### PTS/G

# %%
nhl['PTS/G_13'] = nhl.apply(lambda player: player.PTS_13/player.GP_13, axis=1)
nhl['PTS/G_14'] = nhl.apply(lambda player: player.PTS_14/player.GP_14, axis=1)
nhl['PTS/G_15'] = nhl.apply(lambda player: player.PTS_15/player.GP_15, axis=1)
nhl['PTS/G_16'] = nhl.apply(lambda player: player.PTS_16/player.GP_16, axis=1)
nhl['PTS/G_17'] = nhl.apply(lambda player: player.PTS_17/player.GP_17, axis=1)
nhl['PTS/G_18'] = nhl.apply(lambda player: player.PTS_18/player.GP_18, axis=1)

# %% [markdown]
# ### $/PTS

# %%
def moneyPerPts(player, pts_year, gp_year, cap_year):
    if player[pts_year] > 0:
        return ((player[gp_year]/82) * player[cap_year]) / player[pts_year]
    else:
        return ((player[gp_year]/82) * player[cap_year])

# %%
nhl['Cap Cost_13'] = nhl['Cap Cost_13'].replace('[\$,]', '', regex=True).astype(float)
nhl['$/PTS_13'] = nhl.apply(lambda player: moneyPerPts(player, 'PTS_13', 'GP_13', 'Cap Cost_13'), axis=1)

# %%
nhl['Cap Cost_14'] = nhl['Cap Cost_14'].replace('[\$,]', '', regex=True).astype(float)
nhl['$/PTS_14'] = nhl.apply(lambda player: moneyPerPts(player, 'PTS_14', 'GP_14', 'Cap Cost_14'), axis=1)

# %%
nhl['Cap Cost_15'] = nhl['Cap Cost_15'].replace('[\$,]', '', regex=True).astype(float)
nhl['Cap Cost_15'] = nhl['Cap Cost_15'].apply(lambda player: player*1000000)
nhl['$/PTS_15'] = nhl.apply(lambda player: moneyPerPts(player, 'PTS_15', 'GP_15', 'Cap Cost_15'), axis=1)

# %%
nhl['Cap Hit_16'] = nhl['Cap Hit_16'].replace('[\$,]', '', regex=True).astype(float)
nhl['Cap Hit_16'] = nhl['Cap Hit_16'].apply(lambda player: player*1000000)
nhl['$/PTS_16'] = nhl.apply(lambda player: moneyPerPts(player, 'PTS_16', 'GP_16', 'Cap Hit_16'), axis=1)

# %%
nhl['Cap Hit_17'] = nhl['Cap Hit_17'].replace('[\$\s,]', '', regex=True).astype(float)
nhl['Cap Hit_17'] = nhl['Cap Hit_17'].apply(lambda player: player/100)
nhl['$/PTS_17'] = nhl.apply(lambda player: moneyPerPts(player, 'PTS_17', 'GP_17', 'Cap Hit_17'), axis=1)

# %%
nhl['Cap Hit_18'] = nhl['Cap Hit_18'].replace('[\$\s,]', '', regex=True).astype(float)
nhl['$/PTS_18'] = nhl.apply(lambda player: moneyPerPts(player, 'PTS_18', 'GP_18', 'Cap Hit_18'), axis=1)

# %% [markdown]
# ### Age Correction

# %%
nhl['Age'] = nhl.Age.apply(lambda age: age+1)

# %% [markdown]
# ### Type Correction

# %%
def p2f(x):
    if x == '#DIV/0!':
        return np.nan
    else:
        return float(x.strip('%').replace(',','.'))

# %%
nhl['ZS%_18'] = nhl[~nhl['ZS%_18'].isna()]['ZS%_18'].apply(lambda feat: p2f(feat)/100)

# %%
nhl['GC_18'] = nhl[~nhl['GC_18'].isna()]['GC_18'].apply(lambda feat: p2f(feat))

# %%
nhl['GS/G_18'] = nhl[~nhl['GS/G_18'].isna()]['GS/G_18'].apply(lambda feat: p2f(feat))
nhl['GS/G_17'] = nhl[~nhl['GS/G_17'].isna()]['GS/G_17'].apply(lambda feat: p2f(feat))

# %%
nhl['OWAR_18'] = nhl[~nhl['OWAR_18'].isna()]['OWAR_18'].apply(lambda feat: p2f(feat))

# %%
nhl['OPS_18'] = nhl[~nhl['OPS_18'].isna()]['OPS_18'].apply(lambda feat: p2f(feat))
nhl['OPS_17'] = nhl[~nhl['OPS_17'].isna()]['OPS_17'].apply(lambda feat: p2f(feat))

# %%
nhl['PDO_18'] = nhl[~nhl['PDO_18'].isna()]['PDO_18'].apply(lambda feat: 1-p2f(feat))
nhl['PDO_17'] = nhl[~nhl['PDO_17'].isna()]['PDO_17'].apply(lambda feat: 1-p2f(feat))

# %% [markdown]
# ### Fix Units

# %%
nhl['PAX_18'] = nhl['PAX_18'].replace(',', '.', regex=True).astype(float)

# %%
nhl['Sh%_13'] = nhl[~nhl['Sh%_13'].isna()]['Sh%_13'].apply(lambda feat: p2f(feat)/100)
nhl['Sh%_14'] = nhl[~nhl['Sh%_14'].isna()]['Sh%_14'].apply(lambda feat: p2f(feat)/100)
nhl['Sh%_15'] = nhl[~nhl['Sh%_15'].isna()]['Sh%_15'].apply(lambda feat: p2f(feat)/100)
nhl['Sh%_16'] = nhl[~nhl['Sh%_16'].isna()]['Sh%_16'].apply(lambda feat: p2f(feat)/100)

# %%
nhl['Sh%_17'] = nhl['Sh%_17'].replace(',', '.', regex=True)
nhl['Sh%_17'] = nhl[~nhl['Sh%_17'].isna()]['Sh%_17'].apply(lambda feat: p2f(feat)/100)
nhl['Sh%_18'] = nhl['Sh%_18'].replace(',', '.', regex=True)
nhl['Sh%_18'] = nhl[~nhl['Sh%_18'].isna()]['Sh%_18'].apply(lambda feat: p2f(feat)/100)

# %%
nhl['TOI/G_17'] = nhl['TOI/G_17'].replace(',', '.', regex=True).astype(float)
nhl['TOI/G_18'] = nhl['TOI/G_18'].replace(',', '.', regex=True).astype(float)

# %%
nhl['Star'] = nhl['Star'].replace(',', '.', regex=True).astype(float)

# %% [markdown]
# ### Keep last team only

# %%
nhl['Team'] = nhl.Team.apply(lambda tm: str(tm).split(',')[-1])

# %% [markdown]
# ### Variance
#
# #### Of GP

# %%
def getGPVariance(player):
    GP = []
    # Lock out year
    # if not math.isnan(player.GP_13):
    #   GP.append(player.GP_13)
    if not math.isnan(player.GP_14):
        GP.append(player.GP_14)
    if not math.isnan(player.GP_15):
        GP.append(player.GP_15)
    if not math.isnan(player.GP_16):
        GP.append(player.GP_16)
    if not math.isnan(player.GP_17):
        GP.append(player.GP_17)
    if not math.isnan(player.GP_18):
        GP.append(player.GP_18)
        
    return np.var(GP)
    
nhl['GP_var'] = nhl.apply(lambda player: getGPVariance(player), axis=1)
# Out:
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### Of PTS

# %%
def getPTSVariance(player):
    PTS = []
    # Lock out year
    # if not math.isnan(player.PTS_13):
    #     PTS.append(player.PTS_13)
    if not math.isnan(player.PTS_14):
        PTS.append(player.PTS_14)
    if not math.isnan(player.PTS_15):
        PTS.append(player.PTS_15)
    if not math.isnan(player.PTS_16):
        PTS.append(player.PTS_16)
    if not math.isnan(player.PTS_17):
        PTS.append(player.PTS_17)
    if not math.isnan(player.PTS_18):
        PTS.append(player.PTS_18)
        
    return np.var(PTS)
    
nhl['PTS_var'] = nhl.apply(lambda player: getPTSVariance(player), axis=1)
# Out:
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### Of PTS/G

# %%
def getPTS_GVariance(player):
    PTS_G = []
    if not math.isnan(player['PTS/G_13']):
        PTS_G.append(player['PTS/G_13'])
    if not math.isnan(player['PTS/G_14']):
        PTS_G.append(player['PTS/G_14'])
    if not math.isnan(player['PTS/G_15']):
        PTS_G.append(player['PTS/G_15'])
    if not math.isnan(player['PTS/G_16']):
        PTS_G.append(player['PTS/G_16'])
    if not math.isnan(player['PTS/G_17']):
        PTS_G.append(player['PTS/G_17'])
    if not math.isnan(player['PTS/G_18']):
        PTS_G.append(player['PTS/G_18'])
        
    return np.var(PTS_G)
    
nhl['PTS/G_var'] = nhl.apply(lambda player: getPTS_GVariance(player), axis=1)
# Out:
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### Mean
#
# #### Of GP

# %%
def getGPMean(player):
    GP = []
    # if not math.isnan(player.GP_13):
    #     GP.append(player.GP_13)
    if not math.isnan(player.GP_14):
        GP.append(player.GP_14)
    if not math.isnan(player.GP_15):
        GP.append(player.GP_15)
    if not math.isnan(player.GP_16):
        GP.append(player.GP_16)
    if not math.isnan(player.GP_17):
        GP.append(player.GP_17)
    if not math.isnan(player.GP_18):
        GP.append(player.GP_18)
        
    return np.mean(GP)
    
nhl['GP_mean'] = nhl.apply(lambda player: getGPMean(player), axis=1)
# Out:
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### Of PTS

# %%
def getPTSMean(player):
    PTS = []
    # if not math.isnan(player.PTS_13):
    #     PTS.append(player.PTS_13)
    if not math.isnan(player.PTS_14):
        PTS.append(player.PTS_14)
    if not math.isnan(player.PTS_15):
        PTS.append(player.PTS_15)
    if not math.isnan(player.PTS_16):
        PTS.append(player.PTS_16)
    if not math.isnan(player.PTS_17):
        PTS.append(player.PTS_17)
    if not math.isnan(player.PTS_18):
        PTS.append(player.PTS_18)
        
    return np.mean(PTS)
    
nhl['PTS_mean'] = nhl.apply(lambda player: getPTSMean(player), axis=1)
# Out:
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### Of PTS/G

# %%
def getPTS_GMean(player):
    PTS_G = []
    if not math.isnan(player['PTS/G_13']):
        PTS_G.append(player['PTS/G_13'])
    if not math.isnan(player['PTS/G_14']):
        PTS_G.append(player['PTS/G_14'])
    if not math.isnan(player['PTS/G_15']):
        PTS_G.append(player['PTS/G_15'])
    if not math.isnan(player['PTS/G_16']):
        PTS_G.append(player['PTS/G_16'])
    if not math.isnan(player['PTS/G_17']):
        PTS_G.append(player['PTS/G_17'])
    if not math.isnan(player['PTS/G_18']):
        PTS_G.append(player['PTS/G_18'])
        
    return np.mean(PTS_G)
    
nhl['PTS/G_mean'] = nhl.apply(lambda player: getPTS_GMean(player), axis=1)
# Out:
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/noiseuce/miniconda3/envs/pool/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ---
# ## Contracts
#
# ### Forwards

# %%
nhl_att_contracts = pd.read_csv('/mnt/c/Users/cedric/Dropbox/Pool-Att.csv', header=1, encoding = "utf-8")
# nhl_att_contracts = pd.read_csv(r'C:\Users\Maison\Dropbox\Pool-Att.csv', header=1, encoding = "utf-8")
# nhl_att_contracts = pd.read_csv('~/Dropbox/Pool-Att.csv', header=1, encoding = "utf-8")

# %%
nhl_att_contracts['Name'] = nhl_att_contracts.Attaquant.apply(lambda player: re.sub(r'\W+', '', f'{player}').upper())

# %%
nhl_att_contracts.set_index('Name', inplace=True)

# %%
nhl_att_contracts.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl_att_contracts.head()
# Out:
#               Tier       Attaquant   TM  AGE    12    13    14    15    16  \
# Name
# KANEPATRICK    NaN    Kane Patrick  CHI   28  82.0  47.0  69.0  61.0  82.0
# TOEWSJONATHAN  NaN  Toews Jonathan  CHI   28  59.0  47.0  76.0  81.0  80.0
# KOPITARANZE    NaN    Kopitar Anze  LAK   29  82.0  47.0  82.0  79.0  81.0
# OVECHKINALEX   NaN   Ovechkin Alex  WSH   31  78.0  48.0  78.0  81.0  79.0
# BENNJAMIE      NaN      Benn Jamie  DAL   27  71.0  41.0  81.0  82.0  82.0
#
#                GP (17)     ...       Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# Name                       ...
# KANEPATRICK       82.0     ...                 4          8.9            8
# TOEWSJONATHAN     72.0     ...                 4          6.6            8
# KOPITARANZE       76.0     ...                 4          5.6            6
# OVECHKINALEX      82.0     ...                 4          6.9            8
# BENNJAMIE         77.0     ...                 4          7.3            8
#
#                Unnamed: 43  Unnamed: 44  CONST  EVOL  PDO.1  Unnamed: 48  \
# Name
# KANEPATRICK            3.0          3.0      3     3   -3.0          NaN
# TOEWSJONATHAN          1.5          2.3      4     2   -1.1          NaN
# KOPITARANZE            1.5          2.3      3     2    1.4          NaN
# OVECHKINALEX           3.0          3.0      4     2   -2.5          NaN
# BENNJAMIE              3.0          2.3      4     2    1.3          NaN
#
#                Unnamed: 49
# Name
# KANEPATRICK      29.900000
# TOEWSJONATHAN    27.255556
# KOPITARANZE      25.760526
# OVECHKINALEX     28.400000
# BENNJAMIE        31.898052
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Defensemen

# %%
nhl_def_contracts = pd.read_csv('/mnt/c/Users/cedric/Dropbox/Pool-Def.csv', header=1, encoding = "utf-8")
# nhl_def_contracts = pd.read_csv(r'C:\Users\Maison\Dropbox\Pool-Def.csv', header=1, encoding = "utf-8")
# nhl_def_contracts = pd.read_csv('~/Dropbox/Pool-Def.csv', header=1, encoding = "utf-8")

# %%
nhl_def_contracts['Name'] = nhl_def_contracts.Defenseur.apply(lambda player: re.sub(r'\W+', '', f'{player}').upper())

# %%
nhl_def_contracts.set_index('Name', inplace=True)

# %%
nhl_def_contracts.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl_def_contracts.head()
# Out:
#                 Tier         Defenseur   TM   AGE  12  13  14    15    16  \
# Name
# SUBBANPK         NaN      Subban P.K.   MTL  28.0  81  42  82  82.0  68.0
# BURNSBRENT         x      Burns Brent   SJS  32.0  81  30  69  82.0  82.0
# HEDMANVICTOR       x    Hedman Victor   TBL  27.0  61  44  75  59.0  78.0
# WEBERSHEA        NaN       Weber Shea   MTL  32.0  78  48  79  78.0  78.0
# BYFUGLIENDUSTIN    x  Byfuglien Dustin  WPG  32.0  66  43  78  69.0  81.0
#
#                  GP (17)     ...      Unnamed: 40 Unnamed: 41  Unnamed: 42  \
# Name                         ...
# SUBBANPK            66.0     ...                4         5.0            8
# BURNSBRENT          82.0     ...                4         7.6            8
# HEDMANVICTOR        79.0     ...                4         7.5            8
# WEBERSHEA           78.0     ...                4         4.4            8
# BYFUGLIENDUSTIN     80.0     ...                4         5.3            8
#
#                  Unnamed: 43  Unnamed: 44  CONST  EVOL  PDO.1  Unnamed: 48  \
# Name
# SUBBANPK                 1.5          2.3      4     2    1.4          NaN
# BURNSBRENT               4.5          3.0      4     3   -1.9          NaN
# HEDMANVICTOR             4.5          2.3      3     4   -3.1          NaN
# WEBERSHEA                3.0          3.0      3     2   -2.5          NaN
# BYFUGLIENDUSTIN          3.0          3.0      4     2    0.3          NaN
#
#                  Unnamed: 49
# Name
# SUBBANPK           28.119697
# BURNSBRENT         32.200000
# HEDMANVICTOR       30.123418
# WEBERSHEA          24.915385
# BYFUGLIENDUSTIN    29.630000
#
# [5 rows x 50 columns]

# %% [markdown]
# ### All

# %%
nhl_contracts = pd.concat([nhl_att_contracts, nhl_def_contracts], sort=True)

# %%
nhl = nhl.join(nhl_contracts.END)

# %%
nhl = nhl.join(nhl_contracts.SALARY)

# %%
nhl['SALARY'] = nhl['SALARY'].replace(',', '', regex=True).astype(float)

# %% [markdown]
# ---
# ## Reformat

# %%
nhl.columns
# Out:
# Index(['Last_Name', 'First_Name', 'Team', 'Age', 'Position', 'GP_13', 'GP_14',
#        'GP_15', 'GP_16', 'GP_17', 'GP_18', 'G_13', 'G_14', 'G_15', 'G_16',
#        'G_17', 'G_18', 'A_13', 'A_14', 'A_15', 'A_16', 'A_17', 'A_18',
#        'PTS_13', 'PTS_14', 'PTS_15', 'PTS_16', 'PTS_17', 'PTS_18', 'PAX_18',
#        'Sh%_13', 'Sh%_14', 'Sh%_15', 'Sh%_16', 'Sh%_17', 'Sh%_18', 'iSF_13',
#        'iSF_14', 'iSF_15', 'iSF_16', 'iSF_17', 'iSF_18', 'TOI/G_13',
#        'TOI/G_14', 'TOI/G_15', 'TOI/G_16', 'TOI/G_17', 'TOI/G_18',
#        'PPTOI/GP_17', 'PPTOI/GP_18', 'ZS%_18', 'GC_18', 'SCF_17', 'SCF_18',
#        'GS/G_17', 'GS/G_18', 'OWAR_18', 'OPS_17', 'OPS_18', 'PDO_17', 'PDO_18',
#        'iCF_17', 'iCF_18', 'iFF_17', 'iFF_18', 'Star', 'Salary_18',
#        'Cap Cost_13', 'Cap Cost_14', 'Cap Cost_15', 'Cap Hit_16', 'Cap Hit_17',
#        'Cap Hit_18', 'PTS/G_13', 'PTS/G_14', 'PTS/G_15', 'PTS/G_16',
#        'PTS/G_17', 'PTS/G_18', '$/PTS_13', '$/PTS_14', '$/PTS_15', '$/PTS_16',
#        '$/PTS_17', '$/PTS_18', 'GP_var', 'PTS_var', 'PTS/G_var', 'GP_mean',
#        'PTS_mean', 'PTS/G_mean', 'END', 'SALARY'],
#       dtype='object')

# %%
nhl = nhl[['Last_Name', 'First_Name', 'Team', 'Age', 'Position', 
           'GP_13', 'GP_14', 'GP_15', 'GP_16', 'GP_17', 'GP_18', 'GP_mean', 'GP_var',
           'G_13', 'G_14', 'G_15', 'G_16', 'G_17', 'G_18', 
           'A_13', 'A_14', 'A_15', 'A_16', 'A_17', 'A_18',
           'PTS_13', 'PTS_14', 'PTS_15', 'PTS_16', 'PTS_17', 'PTS_18', 'PTS_mean', 'PTS_var', 
           'PAX_18',
           'PTS/G_13', 'PTS/G_14', 'PTS/G_15', 'PTS/G_16', 'PTS/G_17', 'PTS/G_18', 'PTS/G_mean', 'PTS/G_var',
           '$/PTS_13', '$/PTS_14', '$/PTS_15', '$/PTS_16', '$/PTS_17', '$/PTS_18',
           'Sh%_13', 'Sh%_14', 'Sh%_15', 'Sh%_16', 'Sh%_17', 'Sh%_18', 
           'iSF_13', 'iSF_14', 'iSF_15', 'iSF_16', 'iSF_17', 'iSF_18', 
           'TOI/G_13', 'TOI/G_14', 'TOI/G_15', 'TOI/G_16', 'TOI/G_17', 'TOI/G_18',
           'PPTOI/GP_17', 'PPTOI/GP_18', 
           'ZS%_18', # Zone start percentage, the percentage of shifts started in the offensive zone, not counting neutral zone or on-the-fly changes
           'GC_18', # Goals Created, which is half-point for a goal, and a variable amount depending on the team's assists per goal
           'SCF_17', 'SCF_18', # Team scoring chances while this player was on the ice
           'GS/G_17', 'GS/G_18', # The player's average game score
           'OWAR_18', # Offensive wins above replacement, a catch-all stat that measures a player's offensive contributions in terms of wins
           'OPS_17','OPS_18', # Offensive point shares, a catch-all stats that measures a player's offensive contributions in points in the standings
           'PDO_17', 'PDO_18', # The team's shooting and save percentages added together, times a thousand
           'iCF_17', 'iCF_18', # Shot attempts (Corsi, SAT) taken by this individual
           'iFF_17', 'iFF_18', # Unblocked shot attempts (Fenwick, USAT) taken by this individual
           'Cap Cost_13', 'Cap Cost_14', 'Cap Cost_15', 'Cap Hit_16', 'Cap Hit_17', 'Cap Hit_18', 
           'END',
           'Star']]

# %%
nhl.head()
# Out:
#                    Last_Name First_Name  Team   Age Position  GP_13  GP_14  \
# Name
# ABDELKADERJUSTIN  Abdelkader     Justin   DET  31.0       LW   48.0   70.0
# ABERGPONTUS            Aberg     Pontus   EDM  25.0       LW    NaN    NaN
# ACCIARINOEL          Acciari       Noel   BOS  27.0        C    NaN    NaN
# AGOSTINOKENNY       Agostino      Kenny   BOS  26.0       LW    NaN    8.0
# AHOSEBASTIAN             Aho  Sebastian   NYI  22.0        D    NaN    NaN
#
#                   GP_15  GP_16  GP_17   ...    iFF_17  iFF_18  Cap Cost_13  \
# Name                                    ...
# ABDELKADERJUSTIN   71.0   82.0   64.0   ...     138.0   164.0    1800000.0
# ABERGPONTUS         NaN    NaN   15.0   ...      15.0   101.0          NaN
# ACCIARINOEL         NaN   19.0   29.0   ...       NaN    92.0          NaN
# AGOSTINOKENNY       NaN    2.0    7.0   ...      24.0    16.0          NaN
# AHOSEBASTIAN        NaN    NaN   82.0   ...     285.0    33.0          NaN
#
#                   Cap Cost_14  Cap Cost_15  Cap Hit_16  Cap Hit_17  \
# Name
# ABDELKADERJUSTIN    1800000.0    1800000.0   1800000.0   4250000.0
# ABERGPONTUS               NaN          NaN         NaN    780833.0
# ACCIARINOEL               NaN          NaN    793000.0    792500.0
# AGOSTINOKENNY        900000.0          NaN    830000.0    625000.0
# AHOSEBASTIAN              NaN          NaN         NaN    925000.0
#
#                   Cap Hit_18   END    Star
# Name
# ABDELKADERJUSTIN   4250000.0  23.0  2.1930
# ABERGPONTUS         650000.0  19.0  0.9651
# ACCIARINOEL         725000.0  19.0  0.7466
# AGOSTINOKENNY       875000.0  18.0  0.0125
# AHOSEBASTIAN        770000.0  19.0  0.4247
#
# [5 rows x 91 columns]

# %% [markdown]
# ### Find Players with Different Names through time

# %%
# def find_names(plyr):
#     print(f'{plyr.Last_Name} {plyr.First_Name}')
#     print('...')
#     lastname = re.sub(r'\W+', '', f'{plyr.Last_Name}').upper()
#     for name in nhl.index.values:
#         index = name.find(lastname)
#         if index > -1:
#             print(f' => {name}')
#     print('...')
    
# nhl.apply(lambda plyr: find_names(plyr), axis=1)

# %% [markdown]
# ---
# ## Player score

# %%
def normalizeFeature(feature):
    #Normalized Data
    return (feature-min(feature))/(max(feature)-min(feature))

# %%
def getPlayerScore(player):
    name = player.name
    return -normalizeFeature(nhl.GP_var)[name] + normalizeFeature(nhl.GP_mean)[name] - normalizeFeature(nhl.PTS_var)[name] + normalizeFeature(nhl.PTS_mean)[name] - \
            normalizeFeature(nhl['PTS/G_var'])[name] + normalizeFeature(nhl['PTS/G_mean'])[name] - normalizeFeature(nhl['$/PTS_18'])[name] + \
            normalizeFeature(nhl['PPTOI/GP_18'])[name] + normalizeFeature(nhl['ZS%_18'])[name] + normalizeFeature(nhl['GC_18'])[name] + \
            normalizeFeature(nhl['SCF_18'])[name] + normalizeFeature(nhl['GS/G_18'])[name] + normalizeFeature(nhl['OWAR_18'])[name] + \
            normalizeFeature(nhl['OPS_18'])[name] + normalizeFeature(nhl['PDO_18'])[name] + normalizeFeature(nhl['iCF_18'])[name] + \
            normalizeFeature(nhl['iFF_18'])[name]

# %%
nhl['Score'] = nhl.apply(lambda player: getPlayerScore(player), axis=1)

# %%
nhl.sort_values(['Score'], ascending=False).head(10)
# Out:
#                  Last_Name First_Name Team   Age Position  GP_13  GP_14  \
# Name
# OVECHKINALEX      Ovechkin       Alex  WSH  33.0       LW   48.0   78.0
# MCDAVIDCONNOR      McDavid     Connor  EDM  22.0        C    NaN    NaN
# CROSBYSIDNEY        Crosby     Sidney  PIT  31.0        C   36.0   80.0
# KUCHEROVNIKITA    Kucherov     Nikita  TBL  25.0       RW    NaN   52.0
# MALKINEVGENI        Malkin     Evgeni  PIT  32.0        C   31.0   60.0
# MACKINNONNATHAN  MacKinnon     Nathan  COL  23.0        C    NaN   82.0
# KESSELPHIL          Kessel       Phil  PIT  31.0       RW   48.0   82.0
# SEGUINTYLER         Seguin      Tyler  DAL  27.0        C   48.0   80.0
# BURNSBRENT           Burns      Brent  SJS  33.0        D   30.0   69.0
# GIROUXCLAUDE        Giroux     Claude  PHI  31.0        C   48.0   82.0
#
#                  GP_15  GP_16  GP_17    ...      iFF_18  Cap Cost_13  \
# Name                                    ...
# OVECHKINALEX      81.0   79.0   82.0    ...       526.0    9538462.0
# MCDAVIDCONNOR      NaN   45.0   82.0    ...       357.0          NaN
# CROSBYSIDNEY      77.0   80.0   75.0    ...       341.0    8700000.0
# KUCHEROVNIKITA    82.0   77.0   74.0    ...       422.0          NaN
# MALKINEVGENI      69.0   57.0   62.0    ...       306.0    8700000.0
# MACKINNONNATHAN   64.0   72.0   82.0    ...       393.0          NaN
# KESSELPHIL        82.0   82.0   82.0    ...       327.0    5400000.0
# SEGUINTYLER       71.0   72.0   82.0    ...       444.0     900000.0
# BURNSBRENT        82.0   82.0   82.0    ...       481.0    5760000.0
# GIROUXCLAUDE      81.0   78.0   82.0    ...       251.0    3750000.0
#
#                  Cap Cost_14  Cap Cost_15  Cap Hit_16  Cap Hit_17  Cap Hit_18  \
# Name
# OVECHKINALEX       9538462.0    9538000.0   9538000.0   9538462.0   9538462.0
# MCDAVIDCONNOR            NaN          NaN    925000.0    925000.0    925000.0
# CROSBYSIDNEY       8700000.0    8700000.0   8700000.0   8700000.0   8700000.0
# KUCHEROVNIKITA      894167.0     889000.0    712000.0   4766667.0   4766667.0
# MALKINEVGENI       8700000.0    9500000.0   9500000.0   9500000.0   9500000.0
# MACKINNONNATHAN    3775000.0    3775000.0    925000.0   6300000.0   6300000.0
# KESSELPHIL         5400000.0    8000000.0   8000000.0   8000000.0   8000000.0
# SEGUINTYLER        5750000.0    5750000.0   5750000.0   5750000.0   5750000.0
# BURNSBRENT         5760000.0    5760000.0   5760000.0   5760000.0   8000000.0
# GIROUXCLAUDE       3750000.0    8275000.0   8275000.0   8275000.0   8275000.0
#
#                   END     Star      Score
# Name
# OVECHKINALEX     21.0  17.1676  10.382087
# MCDAVIDCONNOR    18.0  18.1365   9.695512
# CROSBYSIDNEY     25.0  12.6759   9.428396
# KUCHEROVNIKITA   19.0  14.4986   9.178601
# MALKINEVGENI     22.0  15.3639   9.148459
# MACKINNONNATHAN  23.0  17.1999   9.080860
# KESSELPHIL       22.0  12.1779   9.079078
# SEGUINTYLER      19.0  15.0332   9.000681
# BURNSBRENT       25.0   6.4894   8.957750
# GIROUXCLAUDE     22.0  13.3160   8.838302
#
# [10 rows x 92 columns]

# %% [markdown]
# ---
# ## Salary Correction

# %%
# Salaries of 2018-2019 season
nhl_salaries = pd.read_csv('/mnt/c/Users/cedric/Dropbox/Salaries-2018-2019.csv', header=None, encoding = "utf-8")
# nhl_salaries = pd.read_csv(r'C:\Users\Maison\Dropbox\Salaries-2018-2019.csv', header=None, encoding = "utf-8")
# nhl_salaries = pd.read_csv('~/Dropbox/Salaries-2018-2019.csv', header=None, encoding = "utf-8")

# %%
nhl_salaries.columns = ['Player', 'Team', 'Salary', 'Cap_Hit']

# %%
nhl_salaries['Name'] = nhl_salaries.Player.apply(lambda player: re.sub(r'\W+', '', f'{player}').upper())

# %%
nhl_salaries.set_index('Name', inplace=True)

# %%
nhl_salaries.rename({'BURMISTROVALEX': 'BURMISTROVALEXANDER',
           'BURROWSALEX': 'BURROWSALEXANDRE',
           'CAMMALLERIMIKE': 'CAMMALLERIMICHAEL',
           'DEANGELOTONY': 'DEANGELOANTHONY',
           'DIDOMENICOCHRIS': 'DIDOMENICOCHRISTOPHER',
           'EDLERALEX': 'EDLERALEXANDER',
           'ENSTROMTOBY': 'ENSTROMTOBIAS',
           'FERLANDMICHEAL': 'FERLANDMICHAEL',
           'HINOSTROZAVINNIE': 'HINOSTROZAVINCENT',
           'KULEMINNIKOLAY': 'KULEMINNIKOLAI',
           'MARCHESSAULTJONATHAN': 'AUDYMARCHESSAULTJONATHAN',
           'MATHESONMIKE': 'MATHESONMICHAEL',
           'MORRISSEYJOSH': 'MORRISSEYJOSHUA',
           'PETROVICALEX': 'PETROVICALEXANDER',
           'RADULOVALEX': 'RADULOVALEXANDER',
           'WENNBERGALEX': 'WENNBERGALEXANDER'}, inplace = True)

# %%
nhl_salaries.head()
# Out:
#                        Player Team      Salary     Cap_Hit
# Name
# JOHNTAVARES      John Tavares  TOR  15,900,000  11,000,000
# CAREYPRICE        Carey Price  MTL  15,000,000  10,500,000
# CONNORMCDAVID  Connor McDavid  EDM  15,000,000  12,500,000
# JAMIEBENN          Jamie Benn  DAL  13,000,000   9,500,000
# JONATHANTOEWS  Jonathan Toews  CHI  12,000,000  10,500,000

# %%
# Reverse index of df and join the salaries
nhl = nhl.set_index(nhl.apply(lambda player: re.sub(r'\W+', '', f'{player["First_Name"]}{player["Last_Name"]}').upper(), axis=1)).join(nhl_salaries.Cap_Hit)

# Put index to initial order                                                    
nhl.set_index(nhl.apply(lambda player: re.sub(r'\W+', '', f'{player["Last_Name"]}{player["First_Name"]}').upper(), axis=1), inplace=True)

# %%
# Convert to float
nhl['Cap_Hit'] = nhl['Cap_Hit'].replace(',', '', regex=True).astype(float)

# %%
# If contract ended last year, put ending year to NaN and add manually
nhl.loc[nhl.END == 18, 'END'] = np.nan

# %%
nhl = nhl[['Last_Name', 'First_Name', 'Team', 'Age', 'Position', 
           'GP_13', 'GP_14', 'GP_15', 'GP_16', 'GP_17', 'GP_18', 'GP_mean', 'GP_var',
           'G_13', 'G_14', 'G_15', 'G_16', 'G_17', 'G_18', 
           'A_13', 'A_14', 'A_15', 'A_16', 'A_17', 'A_18',
           'PTS_13', 'PTS_14', 'PTS_15', 'PTS_16', 'PTS_17', 'PTS_18', 'PTS_mean', 'PTS_var', 
           'PAX_18',
           'PTS/G_13', 'PTS/G_14', 'PTS/G_15', 'PTS/G_16', 'PTS/G_17', 'PTS/G_18', 'PTS/G_mean', 'PTS/G_var',
           '$/PTS_13', '$/PTS_14', '$/PTS_15', '$/PTS_16', '$/PTS_17', '$/PTS_18',
           'Sh%_13', 'Sh%_14', 'Sh%_15', 'Sh%_16', 'Sh%_17', 'Sh%_18', 
           'iSF_13', 'iSF_14', 'iSF_15', 'iSF_16', 'iSF_17', 'iSF_18', 
           'TOI/G_13', 'TOI/G_14', 'TOI/G_15', 'TOI/G_16', 'TOI/G_17', 'TOI/G_18',
           'PPTOI/GP_17', 'PPTOI/GP_18', 
           'ZS%_18', # Zone start percentage, the percentage of shifts started in the offensive zone, not counting neutral zone or on-the-fly changes
           'GC_18', # Goals Created, which is half-point for a goal, and a variable amount depending on the team's assists per goal
           'SCF_17', 'SCF_18', # Team scoring chances while this player was on the ice
           'GS/G_17', 'GS/G_18', # The player's average game score
           'OWAR_18', # Offensive wins above replacement, a catch-all stat that measures a player's offensive contributions in terms of wins
           'OPS_17','OPS_18', # Offensive point shares, a catch-all stats that measures a player's offensive contributions in points in the standings
           'PDO_17', 'PDO_18', # The team's shooting and save percentages added together, times a thousand
           'iCF_17', 'iCF_18', # Shot attempts (Corsi, SAT) taken by this individual
           'iFF_17', 'iFF_18', # Unblocked shot attempts (Fenwick, USAT) taken by this individual
           'Cap Cost_13', 'Cap Cost_14', 'Cap Cost_15', 'Cap Hit_16', 'Cap Hit_17', 'Cap Hit_18', 
           'END',
           'Star', 'Score']]
nhl = nhl.sort_values(['Score'], ascending=False)
nhl.head(10)
# Out:
#                  Last_Name First_Name Team   Age Position  GP_13  GP_14  \
# OVECHKINALEX      Ovechkin       Alex  WSH  33.0       LW   48.0   78.0
# MCDAVIDCONNOR      McDavid     Connor  EDM  22.0        C    NaN    NaN
# CROSBYSIDNEY        Crosby     Sidney  PIT  31.0        C   36.0   80.0
# KUCHEROVNIKITA    Kucherov     Nikita  TBL  25.0       RW    NaN   52.0
# MALKINEVGENI        Malkin     Evgeni  PIT  32.0        C   31.0   60.0
# MACKINNONNATHAN  MacKinnon     Nathan  COL  23.0        C    NaN   82.0
# KESSELPHIL          Kessel       Phil  PIT  31.0       RW   48.0   82.0
# SEGUINTYLER         Seguin      Tyler  DAL  27.0        C   48.0   80.0
# BURNSBRENT           Burns      Brent  SJS  33.0        D   30.0   69.0
# GIROUXCLAUDE        Giroux     Claude  PHI  31.0        C   48.0   82.0
#
#                  GP_15  GP_16  GP_17    ...      iFF_18  Cap Cost_13  \
# OVECHKINALEX      81.0   79.0   82.0    ...       526.0    9538462.0
# MCDAVIDCONNOR      NaN   45.0   82.0    ...       357.0          NaN
# CROSBYSIDNEY      77.0   80.0   75.0    ...       341.0    8700000.0
# KUCHEROVNIKITA    82.0   77.0   74.0    ...       422.0          NaN
# MALKINEVGENI      69.0   57.0   62.0    ...       306.0    8700000.0
# MACKINNONNATHAN   64.0   72.0   82.0    ...       393.0          NaN
# KESSELPHIL        82.0   82.0   82.0    ...       327.0    5400000.0
# SEGUINTYLER       71.0   72.0   82.0    ...       444.0     900000.0
# BURNSBRENT        82.0   82.0   82.0    ...       481.0    5760000.0
# GIROUXCLAUDE      81.0   78.0   82.0    ...       251.0    3750000.0
#
#                  Cap Cost_14  Cap Cost_15  Cap Hit_16  Cap Hit_17  Cap Hit_18  \
# OVECHKINALEX       9538462.0    9538000.0   9538000.0   9538462.0   9538462.0
# MCDAVIDCONNOR            NaN          NaN    925000.0    925000.0    925000.0
# CROSBYSIDNEY       8700000.0    8700000.0   8700000.0   8700000.0   8700000.0
# KUCHEROVNIKITA      894167.0     889000.0    712000.0   4766667.0   4766667.0
# MALKINEVGENI       8700000.0    9500000.0   9500000.0   9500000.0   9500000.0
# MACKINNONNATHAN    3775000.0    3775000.0    925000.0   6300000.0   6300000.0
# KESSELPHIL         5400000.0    8000000.0   8000000.0   8000000.0   8000000.0
# SEGUINTYLER        5750000.0    5750000.0   5750000.0   5750000.0   5750000.0
# BURNSBRENT         5760000.0    5760000.0   5760000.0   5760000.0   8000000.0
# GIROUXCLAUDE       3750000.0    8275000.0   8275000.0   8275000.0   8275000.0
#
#                   END     Star      Score
# OVECHKINALEX     21.0  17.1676  10.382087
# MCDAVIDCONNOR     NaN  18.1365   9.695512
# CROSBYSIDNEY     25.0  12.6759   9.428396
# KUCHEROVNIKITA   19.0  14.4986   9.178601
# MALKINEVGENI     22.0  15.3639   9.148459
# MACKINNONNATHAN  23.0  17.1999   9.080860
# KESSELPHIL       22.0  12.1779   9.079078
# SEGUINTYLER      19.0  15.0332   9.000681
# BURNSBRENT       25.0   6.4894   8.957750
# GIROUXCLAUDE     22.0  13.3160   8.838302
#
# [10 rows x 92 columns]

# %%
nhl['Team'] = nhl.Team.apply(lambda tm: str(tm).split(' ,')[-1])

# %%
nhl[~(nhl.index == 'NANNAN') & (nhl.Position == 'D')].to_csv('./nhl_def.csv', sep=';')

# %% [markdown]
# ---
# ## Predictions

# %%
# Read projections
# projections_all = pd.read_csv(r'C:\Users\Maison\Dropbox\ChuckLemieux.csv', encoding = "utf-8")
projections_all = pd.read_csv('/mnt/c/Users/cedric/Dropbox/ChuckLemieux.csv', encoding = "utf-8")

# projections_tsn = pd.read_csv(r'C:\Users\Maison\Dropbox\Cullen.csv', header=2, encoding = "utf-8")
projections_tsn = pd.read_csv('/mnt/c/Users/cedric/Dropbox/Cullen.csv', header=2, encoding = "utf-8")

# %%
# Name index / Sort / Subset
projections_all['Name'] = projections_all.apply(lambda player: re.sub(r'\W+', '', f'{player["Player"]}').upper(), axis=1)
projections_all.set_index('Name', inplace=True)
projections_all.sort_index(inplace=True)
projections_all = projections_all[['Position', 'Chuck\nLemieux', 'NHL', 'ESPN', 'Fantrax', 'TSN']]
                                                                      
# Name index / Sort / Subset                                                                      
projections_tsn['Name'] = projections_tsn.apply(lambda player: re.sub(r'\W+', '', f'{player["PLAYER"]}').upper(), axis=1)
projections_tsn.set_index('Name', inplace=True)
projections_tsn.sort_index(inplace=True)
projections_tsn = projections_tsn[['POS', 'PTS']]

# %% [markdown]
# ### All

# %%
# Reformat nhl df
nhl_for_join = nhl.copy()
nhl_for_join['Name'] = nhl.apply(lambda player: re.sub(r'\W+', '', f'{player["First_Name"]}{player["Last_Name"]}').upper(), axis=1)
nhl_for_join.set_index('Name', inplace=True)
nhl_for_join = nhl_for_join.sort_index()

# %%
# Join
nhl_for_join = nhl_for_join.join(projections_all, lsuffix='_real', rsuffix='_projection')
nhl_for_join = nhl_for_join.sort_values('Last_Name')

# %%
nhl_for_join['Name'] = nhl_for_join.apply(lambda player: re.sub(r'\W+', '', f'{player["Last_Name"]}{player["First_Name"]}').upper(), axis=1)
nhl_for_join.set_index('Name', inplace=True)
nhl_for_join = nhl_for_join.sort_index()

# %%
nhl_for_join[~(nhl_for_join.index == 'NANNAN') & (nhl_for_join.Position_real == 'D')].to_csv('./nhl_projections_def.csv', sep=';')

# %%
nhl_for_join[~(nhl_for_join.index == 'NANNAN') & (nhl_for_join.Position_real == 'D')]
# Out:
#                        Last_Name    First_Name  Team   Age Position_real  \
# Name
# AHOSEBASTIAN                 Aho     Sebastian   NYI  22.0             D
# ALTMARK                      Alt          Mark   COL  27.0             D
# ALZNERKARL                Alzner          Karl   MTL  30.0             D
# ANDERSSONRASMUS        Andersson        Rasmus   CGY  22.0             D
# ANTIPINVICTOR            Antipin        Victor   BUF  26.0             D
# AUVITUYOHANN              Auvitu        Yohann   EDM  29.0             D
# BARBERIOMARK            Barberio          Mark   COL  28.0             D
# BARRIETYSON               Barrie         Tyson   COL  27.0             D
# BARTKOWSKIMATT        Bartkowski          Matt   CGY  30.0             D
# BEARETHAN                   Bear         Ethan   EDM  21.0             D
# BEAUCHEMINFRANCOIS    Beauchemin      Francois   ANA  38.0             D
# BEAULIEUNATHAN          Beaulieu        Nathan   BUF  26.0             D
# BELPEDIOLOUIE           Belpedio         Louie   MIN  22.0             D
# BENNINGMATT              Benning          Matt   EDM  24.0             D
# BENNJORDIE                  Benn        Jordie   MTL  31.0             D
# BIEGAALEX                  Biega          Alex   VAN  30.0             D
# BIEKSAKEVIN               Bieksa         Kevin   ANA  37.0             D
# BIGRASCHRIS               Bigras         Chris   COL  23.0             D
# BITETTOANTHONY           Bitetto       Anthony   NSH  28.0             D
# BOGOSIANZACH            Bogosian          Zach   BUF  28.0             D
# BORGMANANDREAS           Borgman       Andreas   TOR  23.0             D
# BOROWIECKIMARK        Borowiecki          Mark   OTT  29.0             D
# BORTUZZOROBERT          Bortuzzo        Robert   STL  29.0             D
# BOUWMEESTERJAY       Bouwmeester           Jay   STL  35.0             D
# BOWEYMADISON               Bowey       Madison   WSH  23.0             D
# BOYCHUKJOHNNY            Boychuk        Johnny   NYI  35.0             D
# BRAUNJUSTIN                Braun        Justin   SJS  31.0             D
# BRICKLEYDANIEL          Brickley        Daniel   LAK  23.0             D
# BRODIETJ                  Brodie            TJ   CGY  28.0             D
# BRODINJONAS               Brodin         Jonas   MIN  25.0             D
# ...                          ...           ...   ...   ...           ...
# SPURGEONJARED           Spurgeon         Jared   MIN  29.0             D
# STAALMARC                  Staal          Marc   NYR  32.0             D
# STECHERTROY              Stecher          Troy   VAN  24.0             D
# STONEMICHAEL               Stone       Michael   CGY  28.0             D
# STRALMANANTON           Stralman         Anton   TBL  32.0             D
# STREITMARK                Streit          Mark   MTL  41.0             D
# SUBBANPK                  Subban          P.K.   NSH  29.0             D
# SUSTRANDREJ                Sustr        Andrej   TBL  28.0             D
# SUTERRYAN                  Suter          Ryan   MIN  34.0             D
# TANEVCHRISTOPHER           Tanev   Christopher   VAN  29.0             D
# TENNYSONMATT            Tennyson          Matt   BUF  28.0             D
# THEODORESHEA            Theodore          Shea   VGK  23.0             D
# TROTMANZACH              Trotman          Zach   PIT  28.0             D
# TROUBAJACOB               Trouba         Jacob   WPG  24.0             D
# VALIEVRINAT               Valiev         Rinat   MTL  23.0             D
# VANRIEMSDYKTREVOR   van Riemsdyk        Trevor   CAR  27.0             D
# VATANENSAMI              Vatanen          Sami   NJD  27.0             D
# VLASICMARCEDOUARD         Vlasic  Marc-Edouard   SJS  31.0             D
# WARSOFSKYDAVID         Warsofsky         David   COL  28.0             D
# WEBERSHEA                  Weber          Shea   MTL  33.0             D
# WEBERYANNICK               Weber       Yannick   NSH  30.0             D
# WEEGARMACKENZIE           Weegar     MacKenzie   FLA  25.0             D
# WELINSKIANDY            Welinski          Andy   ANA  25.0             D
# WERENSKIZACH            Werenski          Zach   CBJ  21.0             D
# WHITECLOUDZACH        Whitecloud          Zach   VGK  22.0             D
# WIDEMANCHRIS             Wideman         Chris   OTT  29.0             D
# WOLANINCHRISTIAN         Wolanin     Christian   OTT  23.0             D
# YANDLEKEITH               Yandle         Keith   FLA  32.0             D
# ZADOROVNIKITA            Zadorov        Nikita   COL  23.0             D
# ZAITSEVNIKITA            Zaitsev        Nikita   TOR  27.0             D
#
#                     GP_13  GP_14  GP_15  GP_16  GP_17  ...   Cap Hit_18   END  \
# Name                                                   ...
# AHOSEBASTIAN          NaN    NaN    NaN    NaN   82.0  ...     770000.0  19.0
# ALTMARK               NaN    NaN    1.0    NaN    NaN  ...     650000.0   NaN
# ALZNERKARL           48.0   82.0   82.0   82.0   82.0  ...    4625000.0  22.0
# ANDERSSONRASMUS       NaN    NaN    NaN    NaN    1.0  ...     755833.0  20.0
# ANTIPINVICTOR         NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# AUVITUYOHANN          NaN    NaN    NaN    NaN   25.0  ...     700000.0   NaN
# BARBERIOMARK          2.0   49.0   52.0   30.0   60.0  ...     750000.0   NaN
# BARRIETYSON          32.0   64.0   80.0   78.0   74.0  ...    5500000.0  20.0
# BARTKOWSKIMATT       11.0   64.0   47.0   80.0   24.0  ...     612500.0   NaN
# BEARETHAN             NaN    NaN    NaN    NaN    NaN  ...     720000.0   NaN
# BEAUCHEMINFRANCOIS   48.0   70.0   64.0   82.0   81.0  ...    1000000.0   NaN
# BEAULIEUNATHAN        6.0   17.0   64.0   64.0   74.0  ...    2400000.0  19.0
# BELPEDIOLOUIE         NaN    NaN    NaN    NaN    NaN  ...          NaN   NaN
# BENNINGMATT           NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# BENNJORDIE           26.0   78.0   73.0   64.0   71.0  ...    1100000.0  19.0
# BIEGAALEX             NaN    NaN    7.0   51.0   36.0  ...     750000.0   NaN
# BIEKSAKEVIN          36.0   76.0   60.0   71.0   81.0  ...    4000000.0   NaN
# BIGRASCHRIS           NaN    NaN    NaN   31.0    NaN  ...     843333.0   NaN
# BITETTOANTHONY        NaN    NaN    7.0   28.0   29.0  ...     612500.0   NaN
# BOGOSIANZACH         33.0   55.0   62.0   64.0   56.0  ...    5142857.0  20.0
# BORGMANANDREAS        NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# BOROWIECKIMARK        6.0   13.0   63.0   63.0   70.0  ...    1100000.0   NaN
# BORTUZZOROBERT       15.0   54.0   51.0   40.0   38.0  ...    1150000.0  19.0
# BOUWMEESTERJAY       47.0   82.0   72.0   72.0   81.0  ...    5400000.0  19.0
# BOWEYMADISON          NaN    NaN    NaN    NaN    NaN  ...     703333.0   NaN
# BOYCHUKJOHNNY        44.0   75.0   72.0   70.0   66.0  ...    6000000.0  22.0
# BRAUNJUSTIN          41.0   82.0   70.0   80.0   81.0  ...    3800000.0  20.0
# BRICKLEYDANIEL        NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# BRODIETJ             47.0   81.0   81.0   70.0   82.0  ...    4650400.0  20.0
# BRODINJONAS          45.0   79.0   71.0   68.0   68.0  ...    4166667.0  21.0
# ...                   ...    ...    ...    ...    ...  ...          ...   ...
# SPURGEONJARED        39.0   67.0   66.0   77.0   76.0  ...    5187500.0  20.0
# STAALMARC            21.0   72.0   80.0   77.0   72.0  ...    5700000.0  21.0
# STECHERTROY           NaN    NaN    NaN    NaN   71.0  ...     925000.0   NaN
# STONEMICHAEL         40.0   70.0   81.0   75.0   64.0  ...    3500000.0  20.0
# STRALMANANTON        48.0   81.0   82.0   73.0   73.0  ...    4500000.0  19.0
# STREITMARK           48.0   82.0   81.0   62.0   68.0  ...          NaN   NaN
# SUBBANPK             42.0   82.0   82.0   68.0   66.0  ...    9000000.0  22.0
# SUSTRANDREJ           2.0   43.0   72.0   77.0   80.0  ...    1950000.0   NaN
# SUTERRYAN            48.0   82.0   77.0   82.0   82.0  ...    7538462.0  25.0
# TANEVCHRISTOPHER     38.0   64.0   70.0   69.0    NaN  ...    4450000.0   NaN
# TENNYSONMATT          4.0    NaN   27.0   29.0   45.0  ...     650000.0  19.0
# THEODORESHEA          NaN    NaN    NaN   19.0   34.0  ...     863333.0   NaN
# TROTMANZACH           NaN    2.0   27.0   38.0    NaN  ...     650000.0   NaN
# TROUBAJACOB           NaN   65.0   65.0   81.0   60.0  ...    2812500.0   NaN
# VALIEVRINAT           NaN    NaN    NaN   10.0    NaN  ...     778333.0   NaN
# VANRIEMSDYKTREVOR     NaN    NaN   18.0   82.0   58.0  ...     825000.0   NaN
# VATANENSAMI           8.0   48.0   67.0   71.0   71.0  ...    4875000.0  20.0
# VLASICMARCEDOUARD    48.0   81.0   70.0   67.0   75.0  ...    4250000.0   NaN
# WARSOFSKYDAVID        NaN    6.0    4.0   22.0    7.0  ...     675000.0  19.0
# WEBERSHEA            48.0   79.0   78.0   78.0   78.0  ...    7857143.0  26.0
# WEBERYANNICK          6.0   49.0   65.0   45.0   73.0  ...     650000.0   NaN
# WEEGARMACKENZIE       NaN    NaN    NaN    NaN    3.0  ...     675000.0   NaN
# WELINSKIANDY          NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# WERENSKIZACH          NaN    NaN    NaN    NaN   78.0  ...     925000.0  19.0
# WHITECLOUDZACH        NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# WIDEMANCHRIS          NaN    NaN    NaN   64.0   76.0  ...     800000.0   NaN
# WOLANINCHRISTIAN      NaN    NaN    NaN    NaN    NaN  ...     925000.0   NaN
# YANDLEKEITH          48.0   82.0   84.0   82.0   82.0  ...    6350000.0  23.0
# ZADOROVNIKITA         NaN    7.0   60.0   22.0   56.0  ...    2150000.0  19.0
# ZAITSEVNIKITA         NaN    NaN    NaN    NaN   82.0  ...    4500000.0  24.0
#
#                       Star     Score  Position_projection  Chuck\nLemieux  \
# Name
# AHOSEBASTIAN        0.4247  3.013719                 C/LW            67.0
# ALTMARK             0.0019  1.836919                  NaN             NaN
# ALZNERKARL          0.5557  3.556680                  NaN             NaN
# ANDERSSONRASMUS     0.0075  2.372056                  NaN             NaN
# ANTIPINVICTOR       0.3034  3.274368                  NaN             NaN
# AUVITUYOHANN        0.2644  3.202083                  NaN             NaN
# BARBERIOMARK        0.5664  2.997907                  NaN             NaN
# BARRIETYSON         5.3855  7.090033                    D            49.0
# BARTKOWSKIMATT      0.0769  2.225656                  NaN             NaN
# BEARETHAN           0.2036  2.902058                  NaN             NaN
# BEAUCHEMINFRANCOIS  0.9339  4.121762                  NaN             NaN
# BEAULIEUNATHAN      0.1678  3.225223                  NaN             NaN
# BELPEDIOLOUIE       0.0249       NaN                  NaN             NaN
# BENNINGMATT         1.6368  4.828647                  NaN             NaN
# BENNJORDIE          0.9088  4.051895                  NaN             NaN
# BIEGAALEX           0.3976  2.834889                  NaN             NaN
# BIEKSAKEVIN         0.2127  3.185839                  NaN             NaN
# BIGRASCHRIS         0.0041  2.052516                  NaN             NaN
# BITETTOANTHONY      0.2271  2.231076                  NaN             NaN
# BOGOSIANZACH        0.0344  1.832984                  NaN             NaN
# BORGMANANDREAS      0.1020  3.268363                  NaN             NaN
# BOROWIECKIMARK      0.3948  2.822328                  NaN             NaN
# BORTUZZOROBERT      0.5992  3.331797                  NaN             NaN
# BOUWMEESTERJAY      0.5185  2.796010                  NaN             NaN
# BOWEYMADISON        0.1363  3.167284                  NaN             NaN
# BOYCHUKJOHNNY       1.9892  4.221983                  NaN             NaN
# BRAUNJUSTIN         1.7682  4.363398                  NaN             NaN
# BRICKLEYDANIEL      0.0006  2.020654                  NaN             NaN
# BRODIETJ            2.2662  5.683965                    D            33.0
# BRODINJONAS         2.0588  4.047934                  NaN             NaN
# ...                    ...       ...                  ...             ...
# SPURGEONJARED       4.1192  5.643240                    D            39.0
# STAALMARC           0.3354  2.776682                  NaN             NaN
# STECHERTROY         0.7945  3.872189                  NaN             NaN
# STONEMICHAEL        0.7003  3.934740                  NaN             NaN
# STRALMANANTON       1.2130  4.421563                  NaN             NaN
# STREITMARK          0.0002       NaN                  NaN             NaN
# SUBBANPK            5.4057  7.202988                    D            52.0
# SUSTRANDREJ         0.1929  2.894901                  NaN             NaN
# SUTERRYAN           4.2080  6.558380                    D            43.0
# TANEVCHRISTOPHER    1.2424  2.922989                  NaN             NaN
# TENNYSONMATT        0.0125  2.643502                  NaN             NaN
# THEODORESHEA        2.6505  4.944941                    D            41.0
# TROTMANZACH         0.0006  2.457493                  NaN             NaN
# TROUBAJACOB         1.9062  4.873923                    D            40.0
# VALIEVRINAT         0.0000  2.047938                  NaN             NaN
# VANRIEMSDYKTREVOR   0.7538  3.736389                  NaN             NaN
# VATANENSAMI         2.6679  5.288993                    D            32.0
# VLASICMARCEDOUARD   2.6508  5.147609                    D            33.0
# WARSOFSKYDAVID      0.0193  2.183179                  NaN             NaN
# WEBERSHEA           2.4299  5.063363                  NaN             NaN
# WEBERYANNICK        0.0540  2.928958                  NaN             NaN
# WEEGARMACKENZIE     0.4815  2.552327                  NaN             NaN
# WELINSKIANDY        0.0335  2.250898                  NaN             NaN
# WERENSKIZACH        4.1396  6.775617                    D            44.0
# WHITECLOUDZACH      0.0002  2.039492                  NaN             NaN
# WIDEMANCHRIS        0.1587  3.347014                  NaN             NaN
# WOLANINCHRISTIAN    0.0089  2.838529                  NaN             NaN
# YANDLEKEITH         4.1908  6.934866                    D            53.0
# ZADOROVNIKITA       2.0372  3.253463                  NaN             NaN
# ZAITSEVNIKITA       2.0702  3.591049                  NaN             NaN
#
#                      NHL  ESPN  Fantrax   TSN
# Name
# AHOSEBASTIAN        70.0  73.0     75.0  65.0
# ALTMARK              NaN   NaN      NaN   NaN
# ALZNERKARL           NaN   NaN      NaN   NaN
# ANDERSSONRASMUS      NaN   NaN      NaN   NaN
# ANTIPINVICTOR        NaN   NaN      NaN   NaN
# AUVITUYOHANN         NaN   NaN      NaN   NaN
# BARBERIOMARK         NaN   NaN      NaN   NaN
# BARRIETYSON         60.0  64.0     49.0  50.0
# BARTKOWSKIMATT       NaN   NaN      NaN   NaN
# BEARETHAN            NaN   NaN      NaN   NaN
# BEAUCHEMINFRANCOIS   NaN   NaN      NaN   NaN
# BEAULIEUNATHAN       NaN   NaN      NaN   NaN
# BELPEDIOLOUIE        NaN   NaN      NaN   NaN
# BENNINGMATT          NaN   NaN      NaN   NaN
# BENNJORDIE           NaN   NaN      NaN   NaN
# BIEGAALEX            NaN   NaN      NaN   NaN
# BIEKSAKEVIN          NaN   NaN      NaN   NaN
# BIGRASCHRIS          NaN   NaN      NaN   NaN
# BITETTOANTHONY       NaN   NaN      NaN   NaN
# BOGOSIANZACH         NaN   NaN      NaN   NaN
# BORGMANANDREAS       NaN   NaN      NaN   NaN
# BOROWIECKIMARK       NaN   NaN      NaN   NaN
# BORTUZZOROBERT       NaN   NaN      NaN   NaN
# BOUWMEESTERJAY       NaN   NaN      NaN   NaN
# BOWEYMADISON         NaN   NaN      NaN   NaN
# BOYCHUKJOHNNY        NaN   NaN      NaN   NaN
# BRAUNJUSTIN          NaN   NaN      NaN   NaN
# BRICKLEYDANIEL       NaN   NaN      NaN   NaN
# BRODIETJ            33.0  35.0     34.0  34.0
# BRODINJONAS          NaN   NaN      NaN   NaN
# ...                  ...   ...      ...   ...
# SPURGEONJARED       39.0  38.0     33.0  36.0
# STAALMARC            NaN   NaN      NaN   NaN
# STECHERTROY          NaN   NaN      NaN   NaN
# STONEMICHAEL         NaN   NaN      NaN   NaN
# STRALMANANTON        NaN   NaN      NaN   NaN
# STREITMARK           NaN   NaN      NaN   NaN
# SUBBANPK            58.0  56.0     51.0  54.0
# SUSTRANDREJ          NaN   NaN      NaN   NaN
# SUTERRYAN           49.0  49.0     33.0  48.0
# TANEVCHRISTOPHER     NaN   NaN      NaN   NaN
# TENNYSONMATT         NaN   NaN      NaN   NaN
# THEODORESHEA        42.0  36.0     40.0  37.0
# TROTMANZACH          NaN   NaN      NaN   NaN
# TROUBAJACOB         37.0  32.0     35.0  26.0
# VALIEVRINAT          NaN   NaN      NaN   NaN
# VANRIEMSDYKTREVOR    NaN   NaN      NaN   NaN
# VATANENSAMI         40.0  34.0     39.0  32.0
# VLASICMARCEDOUARD   35.0  32.0     31.0  31.0
# WARSOFSKYDAVID       NaN   NaN      NaN   NaN
# WEBERSHEA            NaN   NaN      NaN   NaN
# WEBERYANNICK         NaN   NaN      NaN   NaN
# WEEGARMACKENZIE      NaN   NaN      NaN   NaN
# WELINSKIANDY         NaN   NaN      NaN   NaN
# WERENSKIZACH        45.0  48.0     43.0  44.0
# WHITECLOUDZACH       NaN   NaN      NaN   NaN
# WIDEMANCHRIS         NaN   NaN      NaN   NaN
# WOLANINCHRISTIAN     NaN   NaN      NaN   NaN
# YANDLEKEITH         58.0  53.0     51.0  53.0
# ZADOROVNIKITA        NaN   NaN      NaN   NaN
# ZAITSEVNIKITA        NaN   NaN      NaN   NaN
#
# [306 rows x 98 columns]

# %% [markdown]
# ### Cullen

# %%
# Reformat nhl df
nhl_for_join = nhl.copy()
nhl_for_join['Name'] = nhl.apply(lambda player: re.sub(r'\W+', '', f'{player["First_Name"]}{player["Last_Name"]}').upper(), axis=1)
nhl_for_join.set_index('Name', inplace=True)
nhl_for_join = nhl_for_join.sort_index()

# %%
# Join
nhl_for_join = nhl_for_join.join(projections_tsn, lsuffix='_real', rsuffix='_projection')
nhl_for_join = nhl_for_join.sort_values('Last_Name')

# %%
nhl_for_join['Name'] = nhl_for_join.apply(lambda player: re.sub(r'\W+', '', f'{player["Last_Name"]}{player["First_Name"]}').upper(), axis=1)
nhl_for_join.set_index('Name', inplace=True)
nhl_for_join = nhl_for_join.sort_index()

# %%
nhl_for_join[~(nhl_for_join.index == 'NANNAN') & ~(nhl_for_join.Position == 'D')].to_csv('./nhl_projections_att_cullen.csv', sep=';')

# %%
nhl_for_join[~(nhl_for_join.index == 'NANNAN') & (nhl_for_join.Position == 'D')]
# Out:
#                        Last_Name    First_Name  Team   Age Position  GP_13  \
# Name
# AHOSEBASTIAN                 Aho     Sebastian   NYI  22.0        D    NaN
# ALTMARK                      Alt          Mark   COL  27.0        D    NaN
# ALZNERKARL                Alzner          Karl   MTL  30.0        D   48.0
# ANDERSSONRASMUS        Andersson        Rasmus   CGY  22.0        D    NaN
# ANTIPINVICTOR            Antipin        Victor   BUF  26.0        D    NaN
# AUVITUYOHANN              Auvitu        Yohann   EDM  29.0        D    NaN
# BARBERIOMARK            Barberio          Mark   COL  28.0        D    2.0
# BARRIETYSON               Barrie         Tyson   COL  27.0        D   32.0
# BARTKOWSKIMATT        Bartkowski          Matt   CGY  30.0        D   11.0
# BEARETHAN                   Bear         Ethan   EDM  21.0        D    NaN
# BEAUCHEMINFRANCOIS    Beauchemin      Francois   ANA  38.0        D   48.0
# BEAULIEUNATHAN          Beaulieu        Nathan   BUF  26.0        D    6.0
# BELPEDIOLOUIE           Belpedio         Louie   MIN  22.0        D    NaN
# BENNINGMATT              Benning          Matt   EDM  24.0        D    NaN
# BENNJORDIE                  Benn        Jordie   MTL  31.0        D   26.0
# BIEGAALEX                  Biega          Alex   VAN  30.0        D    NaN
# BIEKSAKEVIN               Bieksa         Kevin   ANA  37.0        D   36.0
# BIGRASCHRIS               Bigras         Chris   COL  23.0        D    NaN
# BITETTOANTHONY           Bitetto       Anthony   NSH  28.0        D    NaN
# BOGOSIANZACH            Bogosian          Zach   BUF  28.0        D   33.0
# BORGMANANDREAS           Borgman       Andreas   TOR  23.0        D    NaN
# BOROWIECKIMARK        Borowiecki          Mark   OTT  29.0        D    6.0
# BORTUZZOROBERT          Bortuzzo        Robert   STL  29.0        D   15.0
# BOUWMEESTERJAY       Bouwmeester           Jay   STL  35.0        D   47.0
# BOWEYMADISON               Bowey       Madison   WSH  23.0        D    NaN
# BOYCHUKJOHNNY            Boychuk        Johnny   NYI  35.0        D   44.0
# BRAUNJUSTIN                Braun        Justin   SJS  31.0        D   41.0
# BRICKLEYDANIEL          Brickley        Daniel   LAK  23.0        D    NaN
# BRODIETJ                  Brodie            TJ   CGY  28.0        D   47.0
# BRODINJONAS               Brodin         Jonas   MIN  25.0        D   45.0
# ...                          ...           ...   ...   ...      ...    ...
# SPURGEONJARED           Spurgeon         Jared   MIN  29.0        D   39.0
# STAALMARC                  Staal          Marc   NYR  32.0        D   21.0
# STECHERTROY              Stecher          Troy   VAN  24.0        D    NaN
# STONEMICHAEL               Stone       Michael   CGY  28.0        D   40.0
# STRALMANANTON           Stralman         Anton   TBL  32.0        D   48.0
# STREITMARK                Streit          Mark   MTL  41.0        D   48.0
# SUBBANPK                  Subban          P.K.   NSH  29.0        D   42.0
# SUSTRANDREJ                Sustr        Andrej   TBL  28.0        D    2.0
# SUTERRYAN                  Suter          Ryan   MIN  34.0        D   48.0
# TANEVCHRISTOPHER           Tanev   Christopher   VAN  29.0        D   38.0
# TENNYSONMATT            Tennyson          Matt   BUF  28.0        D    4.0
# THEODORESHEA            Theodore          Shea   VGK  23.0        D    NaN
# TROTMANZACH              Trotman          Zach   PIT  28.0        D    NaN
# TROUBAJACOB               Trouba         Jacob   WPG  24.0        D    NaN
# VALIEVRINAT               Valiev         Rinat   MTL  23.0        D    NaN
# VANRIEMSDYKTREVOR   van Riemsdyk        Trevor   CAR  27.0        D    NaN
# VATANENSAMI              Vatanen          Sami   NJD  27.0        D    8.0
# VLASICMARCEDOUARD         Vlasic  Marc-Edouard   SJS  31.0        D   48.0
# WARSOFSKYDAVID         Warsofsky         David   COL  28.0        D    NaN
# WEBERSHEA                  Weber          Shea   MTL  33.0        D   48.0
# WEBERYANNICK               Weber       Yannick   NSH  30.0        D    6.0
# WEEGARMACKENZIE           Weegar     MacKenzie   FLA  25.0        D    NaN
# WELINSKIANDY            Welinski          Andy   ANA  25.0        D    NaN
# WERENSKIZACH            Werenski          Zach   CBJ  21.0        D    NaN
# WHITECLOUDZACH        Whitecloud          Zach   VGK  22.0        D    NaN
# WIDEMANCHRIS             Wideman         Chris   OTT  29.0        D    NaN
# WOLANINCHRISTIAN         Wolanin     Christian   OTT  23.0        D    NaN
# YANDLEKEITH               Yandle         Keith   FLA  32.0        D   48.0
# ZADOROVNIKITA            Zadorov        Nikita   COL  23.0        D    NaN
# ZAITSEVNIKITA            Zaitsev        Nikita   TOR  27.0        D    NaN
#
#                     GP_14  GP_15  GP_16  GP_17  ...   Cap Cost_14  \
# Name                                            ...
# AHOSEBASTIAN          NaN    NaN    NaN   82.0  ...           NaN
# ALTMARK               NaN    1.0    NaN    NaN  ...           NaN
# ALZNERKARL           82.0   82.0   82.0   82.0  ...     2800000.0
# ANDERSSONRASMUS       NaN    NaN    NaN    1.0  ...           NaN
# ANTIPINVICTOR         NaN    NaN    NaN    NaN  ...           NaN
# AUVITUYOHANN          NaN    NaN    NaN   25.0  ...           NaN
# BARBERIOMARK         49.0   52.0   30.0   60.0  ...      605000.0
# BARRIETYSON          64.0   80.0   78.0   74.0  ...      900000.0
# BARTKOWSKIMATT       64.0   47.0   80.0   24.0  ...      650000.0
# BEARETHAN             NaN    NaN    NaN    NaN  ...           NaN
# BEAUCHEMINFRANCOIS   70.0   64.0   82.0   81.0  ...     3500000.0
# BEAULIEUNATHAN       17.0   64.0   64.0   74.0  ...     1275000.0
# BELPEDIOLOUIE         NaN    NaN    NaN    NaN  ...           NaN
# BENNINGMATT           NaN    NaN    NaN    NaN  ...           NaN
# BENNJORDIE           78.0   73.0   64.0   71.0  ...      700000.0
# BIEGAALEX             NaN    7.0   51.0   36.0  ...           NaN
# BIEKSAKEVIN          76.0   60.0   71.0   81.0  ...     4600000.0
# BIGRASCHRIS           NaN    NaN   31.0    NaN  ...           NaN
# BITETTOANTHONY        NaN    7.0   28.0   29.0  ...           NaN
# BOGOSIANZACH         55.0   62.0   64.0   56.0  ...     5142857.0
# BORGMANANDREAS        NaN    NaN    NaN    NaN  ...           NaN
# BOROWIECKIMARK       13.0   63.0   63.0   70.0  ...      575000.0
# BORTUZZOROBERT       54.0   51.0   40.0   38.0  ...      600000.0
# BOUWMEESTERJAY       82.0   72.0   72.0   81.0  ...     6680000.0
# BOWEYMADISON          NaN    NaN    NaN    NaN  ...           NaN
# BOYCHUKJOHNNY        75.0   72.0   70.0   66.0  ...     3366667.0
# BRAUNJUSTIN          82.0   70.0   80.0   81.0  ...     1250000.0
# BRICKLEYDANIEL        NaN    NaN    NaN    NaN  ...           NaN
# BRODIETJ             81.0   81.0   70.0   82.0  ...     2125000.0
# BRODINJONAS          79.0   71.0   68.0   68.0  ...     1444167.0
# ...                   ...    ...    ...    ...  ...           ...
# SPURGEONJARED        67.0   66.0   77.0   76.0  ...     2666667.0
# STAALMARC            72.0   80.0   77.0   72.0  ...     3975000.0
# STECHERTROY           NaN    NaN    NaN   71.0  ...           NaN
# STONEMICHAEL         70.0   81.0   75.0   64.0  ...     1150000.0
# STRALMANANTON        81.0   82.0   73.0   73.0  ...     1700000.0
# STREITMARK           82.0   81.0   62.0   68.0  ...     5250000.0
# SUBBANPK             82.0   82.0   68.0   66.0  ...     2875000.0
# SUSTRANDREJ          43.0   72.0   77.0   80.0  ...     1350000.0
# SUTERRYAN            82.0   77.0   82.0   82.0  ...     7538462.0
# TANEVCHRISTOPHER     64.0   70.0   69.0    NaN  ...     1500000.0
# TENNYSONMATT          NaN   27.0   29.0   45.0  ...           NaN
# THEODORESHEA          NaN    NaN   19.0   34.0  ...           NaN
# TROTMANZACH           2.0   27.0   38.0    NaN  ...      900000.0
# TROUBAJACOB          65.0   65.0   81.0   60.0  ...     1827500.0
# VALIEVRINAT           NaN    NaN   10.0    NaN  ...           NaN
# VANRIEMSDYKTREVOR     NaN   18.0   82.0   58.0  ...           NaN
# VATANENSAMI          48.0   67.0   71.0   71.0  ...     1325000.0
# VLASICMARCEDOUARD    81.0   70.0   67.0   75.0  ...     4250000.0
# WARSOFSKYDAVID        6.0    4.0   22.0    7.0  ...      875000.0
# WEBERSHEA            79.0   78.0   78.0   78.0  ...     7857143.0
# WEBERYANNICK         49.0   65.0   45.0   73.0  ...      650000.0
# WEEGARMACKENZIE       NaN    NaN    NaN    3.0  ...           NaN
# WELINSKIANDY          NaN    NaN    NaN    NaN  ...           NaN
# WERENSKIZACH          NaN    NaN    NaN   78.0  ...           NaN
# WHITECLOUDZACH        NaN    NaN    NaN    NaN  ...           NaN
# WIDEMANCHRIS          NaN    NaN   64.0   76.0  ...           NaN
# WOLANINCHRISTIAN      NaN    NaN    NaN    NaN  ...           NaN
# YANDLEKEITH          82.0   84.0   82.0   82.0  ...     5250000.0
# ZADOROVNIKITA         7.0   60.0   22.0   56.0  ...           NaN
# ZAITSEVNIKITA         NaN    NaN    NaN   82.0  ...           NaN
#
#                     Cap Cost_15  Cap Hit_16  Cap Hit_17  Cap Hit_18   END  \
# Name
# AHOSEBASTIAN                NaN         NaN    925000.0    770000.0  19.0
# ALTMARK                 10000.0         NaN         NaN    650000.0   NaN
# ALZNERKARL            2800000.0   2800000.0   2800000.0   4625000.0  22.0
# ANDERSSONRASMUS             NaN         NaN    786667.0    755833.0  20.0
# ANTIPINVICTOR               NaN         NaN         NaN    925000.0   NaN
# AUVITUYOHANN                NaN         NaN    792500.0    700000.0   NaN
# BARBERIOMARK           874000.0    600000.0    750000.0    750000.0   NaN
# BARRIETYSON           2600000.0   2600000.0   5500000.0   5500000.0  20.0
# BARTKOWSKIMATT        1250000.0   1750000.0    612500.0    612500.0   NaN
# BEARETHAN                   NaN         NaN         NaN    720000.0   NaN
# BEAUCHEMINFRANCOIS    3500000.0   4500000.0   4500000.0   1000000.0   NaN
# BEAULIEUNATHAN        1152000.0   1000000.0   1000000.0   2400000.0  19.0
# BELPEDIOLOUIE               NaN         NaN         NaN         NaN   NaN
# BENNINGMATT                 NaN         NaN         NaN    925000.0   NaN
# BENNJORDIE             700000.0    700000.0   1100000.0   1100000.0  19.0
# BIEGAALEX               90000.0    600000.0    750000.0    750000.0   NaN
# BIEKSAKEVIN           4600000.0   4600000.0   4000000.0   4000000.0   NaN
# BIGRASCHRIS                 NaN    874000.0         NaN    843333.0   NaN
# BITETTOANTHONY          46000.0    665000.0    612500.0    612500.0   NaN
# BOGOSIANZACH          5143000.0   5143000.0   5142857.0   5142857.0  20.0
# BORGMANANDREAS              NaN         NaN         NaN    925000.0   NaN
# BOROWIECKIMARK         575000.0   1100000.0   1100000.0   1100000.0   NaN
# BORTUZZOROBERT         600000.0   1050000.0   1050000.0   1150000.0  19.0
# BOUWMEESTERJAY        5400000.0   5400000.0   5400000.0   5400000.0  19.0
# BOWEYMADISON                NaN         NaN         NaN    703333.0   NaN
# BOYCHUKJOHNNY         3367000.0   6000000.0   6000000.0   6000000.0  22.0
# BRAUNJUSTIN           1250000.0   3800000.0   3800000.0   3800000.0  20.0
# BRICKLEYDANIEL              NaN         NaN         NaN    925000.0   NaN
# BRODIETJ              2125000.0   4650000.0   4650400.0   4650400.0  20.0
# BRODINJONAS           1444000.0   4167000.0   4166667.0   4166667.0  21.0
# ...                         ...         ...         ...         ...   ...
# SPURGEONJARED         2667000.0   2667000.0   5187500.0   5187500.0  20.0
# STAALMARC             3975000.0   5700000.0   5700000.0   5700000.0  21.0
# STECHERTROY                 NaN         NaN    925000.0    925000.0   NaN
# STONEMICHAEL          1150000.0   1150000.0   4000000.0   3500000.0  20.0
# STRALMANANTON         4500000.0   4500000.0   4500000.0   4500000.0  19.0
# STREITMARK            5250000.0   5250000.0   5250000.0         NaN   NaN
# SUBBANPK              9000000.0   9000000.0   9000000.0   9000000.0  22.0
# SUSTRANDREJ            874000.0   1450000.0   1450000.0   1950000.0   NaN
# SUTERRYAN             7538000.0   7538000.0   7538462.0   7538462.0  25.0
# TANEVCHRISTOPHER      2000000.0   4450000.0         NaN   4450000.0   NaN
# TENNYSONMATT           259000.0    625000.0    675000.0    650000.0  19.0
# THEODORESHEA                NaN    863000.0    863333.0    863333.0   NaN
# TROTMANZACH            276000.0    625000.0         NaN    650000.0   NaN
# TROUBAJACOB           1827000.0    894000.0   3308824.0   2812500.0   NaN
# VALIEVRINAT                 NaN    778000.0         NaN    778333.0   NaN
# VANRIEMSDYKTREVOR      925000.0    925000.0    825000.0    825000.0   NaN
# VATANENSAMI           1262000.0   1262000.0   4875000.0   4875000.0  20.0
# VLASICMARCEDOUARD     4250000.0   4250000.0   4250000.0   4250000.0   NaN
# WARSOFSKYDAVID         132000.0    600000.0    575000.0    675000.0  19.0
# WEBERSHEA             7857000.0   7857000.0   7857143.0   7857143.0  26.0
# WEBERYANNICK           850000.0   1500000.0    575000.0    650000.0   NaN
# WEEGARMACKENZIE             NaN         NaN    680000.0    675000.0   NaN
# WELINSKIANDY                NaN         NaN         NaN    925000.0   NaN
# WERENSKIZACH                NaN         NaN    925000.0    925000.0  19.0
# WHITECLOUDZACH              NaN         NaN         NaN    925000.0   NaN
# WIDEMANCHRIS                NaN    600000.0    800000.0    800000.0   NaN
# WOLANINCHRISTIAN            NaN         NaN         NaN    925000.0   NaN
# YANDLEKEITH           4658000.0   5250000.0   6350000.0   6350000.0  23.0
# ZADOROVNIKITA         1744000.0    894000.0    894167.0   2150000.0  19.0
# ZAITSEVNIKITA               NaN         NaN    925000.0   4500000.0  24.0
#
#                       Star     Score  POS   PTS
# Name
# AHOSEBASTIAN        0.4247  3.013719   LW  65.0
# ALTMARK             0.0019  1.836919  NaN   NaN
# ALZNERKARL          0.5557  3.556680    D  15.0
# ANDERSSONRASMUS     0.0075  2.372056  NaN   NaN
# ANTIPINVICTOR       0.3034  3.274368  NaN   NaN
# AUVITUYOHANN        0.2644  3.202083  NaN   NaN
# BARBERIOMARK        0.5664  2.997907  NaN   NaN
# BARRIETYSON         5.3855  7.090033    D  50.0
# BARTKOWSKIMATT      0.0769  2.225656  NaN   NaN
# BEARETHAN           0.2036  2.902058  NaN   NaN
# BEAUCHEMINFRANCOIS  0.9339  4.121762  NaN   NaN
# BEAULIEUNATHAN      0.1678  3.225223  NaN   NaN
# BELPEDIOLOUIE       0.0249       NaN  NaN   NaN
# BENNINGMATT         1.6368  4.828647    D  20.0
# BENNJORDIE          0.9088  4.051895  NaN   NaN
# BIEGAALEX           0.3976  2.834889  NaN   NaN
# BIEKSAKEVIN         0.2127  3.185839  NaN   NaN
# BIGRASCHRIS         0.0041  2.052516  NaN   NaN
# BITETTOANTHONY      0.2271  2.231076  NaN   NaN
# BOGOSIANZACH        0.0344  1.832984  NaN   NaN
# BORGMANANDREAS      0.1020  3.268363  NaN   NaN
# BOROWIECKIMARK      0.3948  2.822328  NaN   NaN
# BORTUZZOROBERT      0.5992  3.331797  NaN   NaN
# BOUWMEESTERJAY      0.5185  2.796010  NaN   NaN
# BOWEYMADISON        0.1363  3.167284  NaN   NaN
# BOYCHUKJOHNNY       1.9892  4.221983    D  22.0
# BRAUNJUSTIN         1.7682  4.363398    D  25.0
# BRICKLEYDANIEL      0.0006  2.020654  NaN   NaN
# BRODIETJ            2.2662  5.683965    D  36.0
# BRODINJONAS         2.0588  4.047934  NaN   NaN
# ...                    ...       ...  ...   ...
# SPURGEONJARED       4.1192  5.643240    D  36.0
# STAALMARC           0.3354  2.776682  NaN   NaN
# STECHERTROY         0.7945  3.872189  NaN   NaN
# STONEMICHAEL        0.7003  3.934740  NaN   NaN
# STRALMANANTON       1.2130  4.421563    D  24.0
# STREITMARK          0.0002       NaN  NaN   NaN
# SUBBANPK            5.4057  7.202988    D  54.0
# SUSTRANDREJ         0.1929  2.894901  NaN   NaN
# SUTERRYAN           4.2080  6.558380    D  48.0
# TANEVCHRISTOPHER    1.2424  2.922989  NaN   NaN
# TENNYSONMATT        0.0125  2.643502  NaN   NaN
# THEODORESHEA        2.6505  4.944941    D  37.0
# TROTMANZACH         0.0006  2.457493  NaN   NaN
# TROUBAJACOB         1.9062  4.873923    D  26.0
# VALIEVRINAT         0.0000  2.047938  NaN   NaN
# VANRIEMSDYKTREVOR   0.7538  3.736389  NaN   NaN
# VATANENSAMI         2.6679  5.288993    D  32.0
# VLASICMARCEDOUARD   2.6508  5.147609    D  31.0
# WARSOFSKYDAVID      0.0193  2.183179  NaN   NaN
# WEBERSHEA           2.4299  5.063363    D  34.0
# WEBERYANNICK        0.0540  2.928958  NaN   NaN
# WEEGARMACKENZIE     0.4815  2.552327  NaN   NaN
# WELINSKIANDY        0.0335  2.250898  NaN   NaN
# WERENSKIZACH        4.1396  6.775617    D  44.0
# WHITECLOUDZACH      0.0002  2.039492  NaN   NaN
# WIDEMANCHRIS        0.1587  3.347014  NaN   NaN
# WOLANINCHRISTIAN    0.0089  2.838529  NaN   NaN
# YANDLEKEITH         4.1908  6.934866    D  53.0
# ZADOROVNIKITA       2.0372  3.253463    D  20.0
# ZAITSEVNIKITA       2.0702  3.591049    D  25.0
#
# [306 rows x 94 columns]

# %% [markdown]
# ### Rookies

# %%
rookies_1 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/rookies-1.csv', encoding = "utf-8", header=None, names=['rank', 'name'], sep=';')
rookies_2 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/rookies-2.csv', encoding = "utf-8")
rookies_3 = pd.read_csv('/mnt/c/Users/cedric/Dropbox/rookies-3.csv', encoding = "utf-8")

# %%
rookies_1['Name'] = rookies_1.apply(lambda player: re.sub(r'\W+', '', f'{player["name"]}').upper(), axis=1)
rookies_1.set_index('Name', inplace=True)
rookies_1 = rookies_1.sort_values('rank')

# %%
rookies_2['Name'] = rookies_2.apply(lambda player: re.sub(r'\W+', '', f'{player["Prospect"]}').upper(), axis=1)
rookies_2.set_index('Name', inplace=True)
rookies_2 = rookies_2.sort_values('Sep. 10')

# %%
rookies_3['Name'] = rookies_3.apply(lambda player: re.sub(r'\W+', '', f'{player["Prospect"]}').upper(), axis=1)
rookies_3.set_index('Name', inplace=True)
rookies_3 = rookies_3.sort_values('Sep. 10')

# %%
rookies_def = rookies_2.join(rookies_1)[['Prospect', 'Team', 'type', 'rank']]

# %%
rookies_def = rookies_def.fillna(axis=1, value=50)
rookies_def['rank'] = rookies_def.apply(lambda x: 50-int(x['rank']), axis=1)

# %%
rookies_def['value'] = rookies_def.apply(lambda x: x['type'] + x['rank'], axis=1)
rookies_def.drop(['type', 'rank'], axis=1, inplace=True)

# %%
rookies_def = rookies_def.sort_values('value', ascending=False)
rookies_def.to_csv('./rookies_def.csv', sep=';')

# %%
rookies_att = rookies_3.join(rookies_1)[['Prospect', 'Team', 'type', 'Prospect Rating', 'rank']]

# %%
rookies_att = rookies_att.fillna(axis=1, value=50)
rookies_att['rank'] = rookies_att.apply(lambda x: 50-int(x['rank']), axis=1)

# %%
rookies_att['value'] = rookies_att.apply(lambda x: x['Prospect Rating'] + x['rank'], axis=1)
rookies_att.drop(['Prospect Rating', 'rank'], axis=1, inplace=True)

# %%
rookies_att = rookies_att.sort_values('value', ascending=False)
rookies_att.to_csv('./rookies_att.csv', sep=';')

# %% [markdown]
# ---
# ## Goalers

# %%
nhl_goal = pd.read_csv('/mnt/c/Users/cedric/Dropbox/NHL-Goalies-2017-18-Goalies.csv', encoding = "utf-8")
# nhl13 = pd.read_csv(r'C:\Users\Maison\Dropbox\NHL 2012-13.csv', encoding = "utf-8")
# nhl13 = pd.read_csv('~/Dropbox/NHL 2012-13.csv', encoding = "utf-8")
nhl_goal.columns = [str(col) + '_18' for col in nhl_goal.columns]

# %%
nhl_goal['Name'] = nhl_goal.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_18"]}{player["First Name_18"]}').upper(), axis=1)

# %%
nhl_goal.set_index('Name', inplace=True)

# %%
nhl_goal = nhl_goal[['Last Name_18', 'First Name_18', 'Team(s)_18', 'GP_18', 'W_18', 'OTL_18', 'SO_18']]

# %%
nhl_goal['PTS_18'] = nhl_goal.apply(lambda player: 2*player.W_18+player.OTL_18+player.SO_18, axis=1)

# %%
nhl_goal['PTS/G_18'] = nhl_goal.apply(lambda player: player.PTS_18/player.GP_18, axis=1)

# %%
nhl_goal_contracts = pd.read_csv('/mnt/c/Users/cedric/Dropbox/Pool-Goal.csv', header=1, encoding = "utf-8")
# nhl_att_contracts = pd.read_csv(r'C:\Users\Maison\Dropbox\Pool-Att.csv', header=1, encoding = "utf-8")
# nhl_att_contracts = pd.read_csv('~/Dropbox/Pool-Att.csv', header=1, encoding = "utf-8")

# %%
nhl_goal_contracts['Name'] = nhl_goal_contracts.Gardien.apply(lambda player: re.sub(r'\W+', '', f'{player}').upper())

# %%
nhl_goal_contracts.set_index('Name', inplace=True)

# %%
nhl_goal_contracts.head()
# Out:
#                 Tier           Gardien   TM  #  AGE    12    13    14    15  \
# Name
# LUNDQVISTHENRIK    3  Lundqvist Henrik  NYR  1   35  62.0  43.0  63.0  46.0
# BOBROVSKYSERGEI    1  Bobrovsky Sergei  CBJ  1   29  29.0  38.0  58.0  51.0
# RASKTUUKKA         2       Rask Tuukka  BOS  1   30  23.0  36.0  58.0  70.0
# RINNEPEKKA         x       Rinne Pekka  NSH  1   35  73.0  43.0  24.0  64.0
# PRICECAREY         x       Price Carey  MTL  1   30  65.0  39.0  59.0  66.0
#
#                    16     ...        END  Commentaire  Unnamed: 53  \
# Name                      ...
# LUNDQVISTHENRIK  65.0     ...       21.0          NaN            4
# BOBROVSKYSERGEI  37.0     ...       19.0          NaN            3
# RASKTUUKKA       64.0     ...       21.0          NaN            4
# RINNEPEKKA       66.0     ...       19.0          NaN            3
# PRICECAREY       12.0     ...       18.0          NaN            3
#
#                  Unnamed: 54  Unnamed: 55  Unnamed: 56  CONST  EVOL  \
# Name
# LUNDQVISTHENRIK          6.8            6          1.5      2     1
# BOBROVSKYSERGEI          9.4            8          3.0      1     3
# RASKTUUKKA               8.7            8          3.0      3     3
# RINNEPEKKA               7.4            6          3.0      2     2
# PRICECAREY               8.2            8          3.0      1     2
#
#                  Unnamed: 59  Unnamed: 60
# Name
# LUNDQVISTHENRIK          NaN         21.3
# BOBROVSKYSERGEI          NaN         27.4
# RASKTUUKKA               NaN         29.7
# RINNEPEKKA               NaN         23.4
# PRICECAREY               NaN         25.2
#
# [5 rows x 61 columns]

# %%
nhl_goal = nhl_goal.join(nhl_goal_contracts.END)

# %%
nhl_goal = nhl_goal.join(nhl_goal_contracts.SALARY)

# %%
nhl_goal['SALARY'] = nhl_goal['SALARY'].replace(',', '', regex=True).astype(float)

# %%
# Salaries of 2018-2019 season
nhl_salaries = pd.read_csv('/mnt/c/Users/cedric/Dropbox/Salaries-2018-2019.csv', header=None, encoding = "utf-8")
# nhl_salaries = pd.read_csv(r'C:\Users\Maison\Dropbox\Salaries-2018-2019.csv', header=None, encoding = "utf-8")
# nhl_salaries = pd.read_csv('~/Dropbox/Salaries-2018-2019.csv', header=None, encoding = "utf-8")

# %%
nhl_salaries.columns = ['Player', 'Team', 'Salary', 'Cap_Hit']

# %%
nhl_salaries['Name'] = nhl_salaries.Player.apply(lambda player: re.sub(r'\W+', '', f'{player}').upper())

# %%
nhl_salaries.set_index('Name', inplace=True)

# %%
nhl_salaries.head()
# Out:
#                        Player Team      Salary     Cap_Hit
# Name
# JOHNTAVARES      John Tavares  TOR  15,900,000  11,000,000
# CAREYPRICE        Carey Price  MTL  15,000,000  10,500,000
# CONNORMCDAVID  Connor McDavid  EDM  15,000,000  12,500,000
# JAMIEBENN          Jamie Benn  DAL  13,000,000   9,500,000
# JONATHANTOEWS  Jonathan Toews  CHI  12,000,000  10,500,000

# %%
# Reverse index of df and join the salaries
nhl_goal = nhl_goal.set_index(nhl_goal.apply(lambda player: re.sub(r'\W+', '', f'{player["First Name_18"]}{player["Last Name_18"]}').upper(), axis=1)).join(nhl_salaries.Cap_Hit)

# Put index to initial order                                                    
nhl_goal.set_index(nhl_goal.apply(lambda player: re.sub(r'\W+', '', f'{player["Last Name_18"]}{player["First Name_18"]}').upper(), axis=1), inplace=True)

# %%
# Convert to float
nhl_goal['Cap_Hit'] = nhl_goal['Cap_Hit'].replace(',', '', regex=True).astype(float)

# %%
# If contract ended last year, put ending year to NaN and add manually
nhl_goal.loc[nhl_goal.END == 18, 'END'] = np.nan

# %%
nhl_goal['Team(s)_18'] = nhl_goal['Team(s)_18'].apply(lambda tm: str(tm).split(', ')[-1])

# %%
nhl_goal.head(10)
# Out:
#                   Last Name_18 First Name_18 Team(s)_18  GP_18  W_18  OTL_18  \
# FERGUSONDYLAN         Ferguson         Dylan        VGK      1     0       0
# BUDAJPETER               Budaj         Peter        TBL      8     3       1
# HUTCHINSONMICHAEL   Hutchinson       Michael        WPG      3     2       0
# LACKEDDIE                 Lack         Eddie        NJD      8     2       0
# HAMMONDANDREW          Hammond        Andrew        COL      1     0       0
# HOLTBYBRADEN            Holtby        Braden        WSH     54    34       4
# BOBROVSKYSERGEI      Bobrovsky        Sergei        CBJ     65    37       6
# DARLINGSCOTT           Darling         Scott        CAR     43    13       7
# COREAUJARED             Coreau         Jared        DET      7     0       1
# MILLERRYAN              Miller          Ryan        ANA     28    12       6
#
#                    SO_18  PTS_18  PTS/G_18   END     SALARY    Cap_Hit
# FERGUSONDYLAN          0       0  0.000000   NaN        NaN        NaN
# BUDAJPETER             0       7  0.875000  19.0  1025000.0  1025000.0
# HUTCHINSONMICHAEL      0       4  1.333333   NaN  1150000.0  1300000.0
# LACKEDDIE              0       4  0.500000   NaN  2750000.0   650000.0
# HAMMONDANDREW          0       0  0.000000   NaN  1350000.0        NaN
# HOLTBYBRADEN           0      72  1.333333  20.0  6100000.0  6100000.0
# BOBROVSKYSERGEI        5      85  1.307692  19.0  7425000.0  7425000.0
# DARLINGSCOTT           0      33  0.767442  21.0  4150000.0  4150000.0
# COREAUJARED            0       1  0.142857   NaN        NaN        NaN
# MILLERRYAN             4      34  1.214286  19.0  2000000.0  2000000.0

# %%
nhl_goal[~(nhl_goal.index == 'NANNAN')].to_csv('./nhl_goal.csv', sep=';')
